# %% [markdown]
# # ECE-6524 / CS-6524 Deep Learning
# # Assignment 4 [100 pts]
#
# In this assignment, we will explore Recurrent Neural Networks (RNN) to deal with the data with temporal sequence. Specifically, we will generate captions for images. We will design an encoder-decoder architecture to achieve this. This homework is inspired by Stanford CS231n and UCSD CSE253.
#
# ## Submission guideline for the coding part (Jupyter Notebook)
#
# 1. Click the Save button at the top of the Jupyter Notebook
# 2. Please make sure to have entered your Virginia Tech PID below
# 3. Once you've completed everything (make sure output for all cells are visible), select File -> Download as -> PDF via LaTeX
# 4. Look at the PDF file and make sure all your solutions are displayed correctly there
# 7. Zip all the files along with this notebook (Please don't include the data). Name it as Assignment_3_Code_[YOUR PID NUMBER].zip
# 8. Name your PDF file as Assignment_4_NB_[YOUR PID NUMBER].pdf
# 9. **<span style="color:blue"> Submit your zipped file and the PDF SEPARATELY**</span>
#
# Note: if facing issues with step 3 refer: https://pypi.org/project/notebook-as-pdf/
#
# ## Submission guideline for the coding part (Google Colab)
#
# 1. Click the Save button at the top of the Notebook
# 2. Please make sure to have entered your Virginia Tech PID below
# 3. Follow last two cells in this notebook for guidelines to download pdf file of this notebook
# 4. Look at the PDF file and make sure all your solutions are displayed correctly there
# 5. Zip all the files along with this notebook (Please don't include the data). Name it as Assignment_2_Code_[YOUR PID NUMBER].zip
# 6. Name your PDF file as Assignment_4_NB_[YOUR PID NUMBER].pdf
# 7. **<span style="color:blue"> Submit your zipped file and the PDF SEPARATELY**</span>
#
# **While you are encouraged to discuss with your peers, <span style="color:blue">all work submitted is expected to be your own.</span> <span style="color:red">If you use any information from other resources (e.g. online materials), you are required to cite it below you VT PID. Any violation will result in a 0 mark for the assignment.</span>**

# %% [markdown]
# ### Please Write Your VT PID Here: 906255893
# ### Reference (if any):
#
# http://karpathy.github.io/2015/05/21/rnn-effectiveness/
#
# https://e2eml.school/how_rnns_lstm_work.html
#
# https://github.com/karpathy/char-rnn
#
# https://gist.github.com/karpathy/d4dee566867f8291f086
#
# https://cv-tricks.com/wp-content/uploads/2019/07/ResNet50_architecture-1.png
# (Used this to take a clear look at the ResNet 50 architecture)
#
#
# Used the below to learn how to freeze a layer:
#
# https://discuss.pytorch.org/t/how-the-pytorch-freeze-network-in-some-layers-only-the-rest-of-the-training/7088/3
#
# https://discuss.pytorch.org/t/best-practice-for-freezing-layers/58156
#
# https://discuss.pytorch.org/t/how-the-pytorch-freeze-network-in-some-layers-only-the-rest-of-the-training/7088/3
#
# https://stackoverflow.com/questions/44146655/how-to-convert-pretrained-fc-layers-to-conv-layers-in-pytorch?noredirect=1&lq=1
#
# https://stackoverflow.com/questions/52548174/how-to-remove-the-last-fc-layer-from-a-resnet-model-in-pytorch
#
#
# Used this to learn how to replace the classifier on ResNet 50
#
# https://medium.com/@stepanulyanin/captioning-images-with-pytorch-bc592e5fd1a3
#
# https://towardsdatascience.com/neural-network-embeddings-explained-4d028e6f0526
#
# https://stackoverflow.com/questions/21046417/python-conversion-of-list-of-arrays-to-2d-array
#
# https://stackoverflow.com/questions/27516849/how-to-convert-list-of-numpy-arrays-into-single-numpy-array
#
# https://stackoverflow.com/questions/23525451/how-do-i-transpose-a-list
#
# https://github.com/Mdhvince/Image_Captioning
#
# https://medium.com/@stepanulyanin/captioning-images-with-pytorch-bc592e5fd1a3
#
# https://github.com/goongong/learn_imageCaption/blob/master/models.py
#
# https://www.deeplearningwizard.com/deep_learning/practical_pytorch/pytorch_recurrent_neuralnetwork/#building-a-recurrent-neural-network-with-pytorch
#
# https://github.com/goongong/learn_imageCaption/blob/master/dirve.py
#
# https://github.com/prakashpandey9/Text-Classification-Pytorch/blob/master/models/LSTM.py
#
# https://medium.com/analytics-vidhya/use-pytorch-to-create-an-image-captioning-model-with-cnn-and-seq2seq-lstm-and-train-on-google-e6563cb9f511
#
# https://github.com/Mdhvince/Image_Captioning/blob/master/training.py
#
# https://www.analyticsvidhya.com/blog/2018/04/solving-an-image-captioning-task-using-deep-learning/
#
# https://github.com/rammyram/image_captioning/blob/master/Image_Captioning.ipynb
#
# https://github.com/Mdhvince/Image_Captioning/blob/master/models.py
#
# http://shikib.com/captioning.html
#
#
# Used these to learn how to include the glove pretrained embedding
#
# https://medium.com/@martinpella/how-to-use-pre-trained-word-embeddings-in-pytorch-71ca59249f76
#
# https://stackoverflow.com/questions/49710537/pytorch-gensim-how-to-load-pre-trained-word-embeddings/49802495#49802495
#
# https://nlpython.com/implementing-glove-model-with-pytorch/
#
#
#
# Used this to debug error fromo using pretrained embedding
#
# https://stackoverflow.com/questions/55042931/cudnn-error-cudnn-status-bad-param-can-someone-explain-why-i-am-getting-this-er

# %% [markdown]
# In this homework, you would need to use **Python 3.6+** along with the following packages (**need to update**):
# ```
# 1. pytorch 1.2
# 2. torchvision
# 3. numpy
# 4. matplotlib
# 5. nltk
# ```
# To install pytorch, please follow the instructions on the [Official website](https://pytorch.org/). In addition, the [official document](https://pytorch.org/docs/stable/) could be very helpful when you want to find certain functionalities.

# %%
# import necessary packages and modules
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms
from torch.nn.utils.rnn import pack_padded_sequence
from torch.autograd import Variable
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(torch.cuda.get_device_name()) # GPU name
# Out:
# Tesla T4

# %% [markdown]
# # Image Captioning Using Encoder-Decoder Architecture
#
# Simply, the encoder will take the image as input and encode it into a vector of feature values. The decoder will take this output from encoder as hidden state and starts to predict next words at each step. The following figure illustrates this:
#
# <img src="figs/image_captioning_overview.jpg" width="600">
# Figure 1. An overview of the encoder-decoder architecture
# (image credit: <a href="https://link.springer.com/chapter/10.1007/978-3-030-04780-1_23">Deep Neural Network Based Image Captioning</a>)
#
# You will use a pre-trained CNN as the encoder and Vanilla RNN/LSTM as decoder to predict the captions.

# %% [markdown]
# # Section 1.1 Data
# Download dataset following the instructions. We are gonna use Flickr30k dataset, which consists of 31783 images and 158,915 captions. However, instead of using the whole dataset and "results.csv", we will follow Karpathy's Flickr30k annotations and use "dataset_flickr30k.json". Please move "dataset_flickr30k.json" to "flickr30k_images" folder.
#
# ## How to download the data (ARC)
# Since the original Flickr30K dataset requires application, we will use the dataset from Kaggle.
#
# Step 1: Register a Kaggle account. https://www.kaggle.com/
#
# Step 2: Log into ARC server in the terminal, e.g. Huckleberry.
#
# Step 3: Install required packages.
#
#     - if you're gonna use powerai on Huckleberry
#         # step 1: request for GPU nodes
#         salloc --partition=normal_q --nodes=1 --tasks-per-node=10 --gres=gpu:1 bash
#         # or if you don't want a GPU, it will be faster to get a job
#         salloc --partition=normal_q --nodes=1 --tasks-per-node=10 bash
#         # step 2: load all necessary modules
#         module load gcc cuda Anaconda3 jdk
#         # step 3: activate the virtual environment
#         source activate powerai16_ibm
#         # step 4: for new packages(take tqdm for example)
#         pip install --user kaggle nltk # on hulogin1/hulogin2
#
#     - if you're gonna use your own conda environment, simply type
#         pip install kaggle nltk
# Step 4: Make sure you have kaggle. Type `kaggle`.
#
# Step 5: Download your kaggle.json file from  https://www.kaggle.com/Your_Username/account. In API section, click Create New API Token. Then move you kaggle.json file to the path `/home/your_name_space/.kaggle/kaggle.json`.
#
# Step 6: Download the dataset. Type `kaggle datasets download hsankesara/flickr-image-dataset`.
#
# Step 7: Unzip the dataset. Type `unzip flickr-image-dataset.zip -x "flickr30k_images/flickr30k_images/flickr30k_images/*.jpg" -d "/path-to-Assignment_4/Assignment_4/"`
#
# Step 8: You should have your dataset in `/path-to-Assignment_4/Assignment_4/flickr30k_images/`
#
# Step 9: Move "dataset_flickr30k.json" to "flickr30k_images" folder.
#
# **Note** that you might want to use `nltk.download('punkt')` and `torchvision.models.resnet50(pretrained=True)` before you enter the GPU node.

# %% [markdown]
# ## How to download the data (Google Colab)
# Step 1: Register a Kaggle account.  https://www.kaggle.com/
#
# Step 2: Download your kaggle.json file from  https://www.kaggle.com/Your_Username/account. In API section, click Create New API Token.
#
# Step 3: As we did before, upload all files on Google Drive and open Google Colab.
#
# Step 4: Install required packages.
#
#     ! pip install -q kaggle nltk
#
# Step 5: Insert a cell.
#
#
#     from google.colab import files
#     files.upload()
#
#
#     Upload `kaggle.json` you just downloaded.
#
# Step 6: Move `kaggle.json` to the right place,
#
#
#      ! mkdir ~/.kaggle
#      ! cp kaggle.json ~/.kaggle/
#
#
# Step 7: Change the permission.
#
#     ! chmod 600 ~/.kaggle/kaggle.json
#
# Step 8: Download.
#
#     !kaggle datasets download hsankesara/flickr-image-dataset
#
# Step 9: Move it to your drive and unzip it.
#
#     unzip flickr-image-dataset.zip -x "flickr30k_images/flickr30k_images/flickr30k_images/*.jpg" -d "/path-to-Assignment_4/Assignment_4/"
#
# Step 10: Move "dataset_flickr30k.json" to "flickr30k_images" folder.

# %%
! pip install -q kaggle nltk

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-103e312d-c89a-444c-aa8a-fce250420e5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-103e312d-c89a-444c-aa8a-fce250420e5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"ms7777","key":"e5a7b19ab47ab59da238870f0a49269c"}'}

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download hsankesara/flickr-image-dataset
# Out:
# flickr-image-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip flickr-image-dataset.zip -x "flickr30k_images/flickr30k_images/flickr30k_images/*.jpg" -d "/content/drive/My Drive/DL_Fall_2020/Assignment_4/"

# %% [markdown]
# ### Colab Setup:
# - Below are some basic steps for colab setup.
# - Make changes based on requirements.
# - Comment out in case of ARC or your local device with powerful GPU.
#
# **Note: For Google Colab give proper paths in this notebook and in dataloader.py if required.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
# modify "customized_path_to_homework", path of folder in drive, where you uploaded your homework
path_to_homework = "/content/drive/My Drive/DL_Fall_2020/Assignment_4/"
sys.path.append(path_to_homework)

# %%
from dataloader import Flickr30k, get_loader

# %% [markdown]
# # Section 1.2 Take a look at the data

# %%
# visualize images and captions
print(path_to_homework)
flickr = Flickr30k(split='val', root=path_to_homework)  # load validation set as an example
flickr()
# Out:
# /content/drive/My Drive/DL_Fall_2020/Assignment_4/
# -------flickr30k--------
# image root: /content/drive/My Drive/DL_Fall_2020/Assignment_4/flickr30k_images
# dataset split: val
# the length of the dataset: 1014

# %%
# show a random image and its captions
img_id = np.random.randint(len(flickr))
#img_id = 4379588756
img = flickr.get_img(img_id)
captions = flickr.get_captions(img_id)

plt.figure()
plt.imshow(img)
plt.axis('off')

print(captions)
# Out:
# ['People are all standing together in front of a statue of an animal, and they are all wearing cool-weather clothing.', 'A group of people bundled in cold weather clothing standing in an empty lot with a forest in the background.', 'There is a group of people standing around, looking like they are waiting for something.', 'Group of people outside with a woman in a red jacket and wearing a green scarf.', 'A group of Asians and one Anglo stand outside bundled in winter clothing.']

# %%
del flickr

# %% [markdown]
# # Section 1.3 Build vocabulary
# We need to build a vocabulary for our dataset. The vocabulary stores all the words and their indices. We will use it to embed and recover the words.

# %%
import nltk
import pickle
import json
from tqdm import tqdm
from collections import Counter
nltk.download('punkt') # You can comment this line once you've downloaded 'punkt'

class Vocabulary(object):
    """Simple vocabulary wrapper."""
    def __init__(self):
        self.word2idx = {'<pad>': 0, '<unk>': 1, '<start>': 2, '<end>': 3}  # follow Pytorch padding rules: pad sentence with zero.
        self.idx = 4
        self.idx2word = {v: k for k, v in self.word2idx.items()}

    def __call__(self, key):
        if key not in self.word2idx:
            return self.word2idx['<unk>']
        return self.word2idx[key]

    def __len__(self):
        return len(self.word2idx)

    def add_word(self, word):
        """
        Add new words
        :param word: word
        """
        if word not in self.word2idx:
            self.word2idx[word] = self.idx  # add a new word
            self.idx2word[self.idx] = word
            self.idx += 1

    def reverse(self, value):
        """
        From idx to words.
        :param value: index
        :return:
        """
        if value not in self.idx2word:
            return self.idx2word[1]  # return '<unk>' if the word is unseen before.
        return self.idx2word[value]

def build_vocab(json_file=path_to_homework+ '/flickr30k_images/dataset_flickr30k.json', threshold=3):
    with open(json_file) as f:
            data = json.load(f)
    f.close()
    counter = Counter()
    for img_idx in tqdm(range(len(data['images']))):
        img_annos = data['images'][img_idx]
        for sent_idx in range(len(img_annos['sentids'])):
#             tokens = img_annos['sentences'][sent_idx]['tokens']  # directly load tokens

            caption = img_annos['sentences'][sent_idx]['raw']
            tokens = nltk.tokenize.word_tokenize(caption.lower())
            
            counter.update(tokens)

    # If the number of words is less than threshold we don't count it.
    words = [word for word, cnt in counter.items() if cnt >= threshold]


    # create a Vocabulary class
    vocab = Vocabulary()

    # add words to Vocab
    for i, word in enumerate(words):
        vocab.add_word(word)

    return vocab
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# let's create a vocabulary for future usage
vocab_path = path_to_homework + '/flickr30k_images/vocab.pkl'
if not os.path.isfile(vocab_path):  # if we don't have vocab, create one
    vocab = build_vocab(json_file=path_to_homework + '/dataset_flickr30k.json', threshold=3)
    with open(vocab_path, 'wb') as f:
        pickle.dump(vocab, f)
    print("Total vocabulary size: {}".format(len(vocab)))
    print("Saved the vocabulary wrapper to '{}'".format(vocab_path))
else:  # if we have, load the existing vocab
    with open(vocab_path, 'rb') as f:
        vocab = pickle.load(f)
    print('vocab loaded!')
    print('the size of vocab:', len(vocab))
f.close()
# Out:
# vocab loaded!
# the size of vocab: 9991

# %%
vocab_path = path_to_homework + '/flickr30k_images/vocab.pkl'
with open(vocab_path, 'rb') as f:
    vocab = pickle.load(f)
print('vocab loaded!')
print('the size of vocab:', len(vocab))
# print(vocab.word2idx.keys())
# print(vocab.idx2word)

# check some random words
for i in range(3):
    random_idx = np.random.randint(len(vocab))
    print('word: {}, index: {}'.format(list(vocab.word2idx.keys())[random_idx], vocab(list(vocab.word2idx.keys())[random_idx])))
# Out:
# vocab loaded!
# the size of vocab: 9991
# word: shipping, index: 5465
# word: lime, index: 3108
# word: drayton, index: 3691

# %% [markdown]
# # Section 2 Vanilla RNN [45 pts]
# # Section 2.1 Design the Network: Encoder [5 pts]
# Implement the baseline model by using pre-trained ResNet-50 as the encoder and Vanilla RNN as the decoder. Note that we will remove the last layer (fc layer) of ResNet-50 and add a trainable linear layer to finetune it for our task. During the training, we will **freeze** the layer before the fc layer. The encoder should output a feature vector of a fixed size for each image.

# %%
class Encoder(nn.Module):
    def __init__(self, emb_dim):
        """
        Use ResNet-50 as encoder.
        :param emb_dim: output size of ResNet-50.
        """
        super(Encoder, self).__init__()
        resnet = torchvision.models.resnet50(pretrained=True).to(device)    #call resNet50 with pretrained weights
        ###########Your code###############
        # freeze the parameters
        for param in resnet.parameters():                        # Freeze all gradients to avoid destruction of learned weights
          param.requires_grad = False
        # replace the last layer (fc layer) with a trainable layer for finetuning
        modules = list(resnet.children())[:-1]                    # extract list of all but last layer
        self.resnet = nn.Sequential(*modules)                     # build net using extracted layers
        self.fc = nn.Linear(resnet.fc.in_features, emb_dim)       # append trainable linear layer with input = 2048, output = embedding dimension
        self.bn1 = nn.BatchNorm1d(emb_dim)                      # batch normalization to improve performance 
        self.init_weights()                                     # weight initialization
        
    def init_weights(self):
        # Normal weights, 0 bias
        self.fc.weight.data.normal_(0.0, 0.02)
        self.fc.bias.data.fill_(0)

    def forward(self, x):     
        x = self.resnet(x)                                        # pass input (images) through pretrained resnet, input = Num of images, output = 2048
        x = x.view(x.size(0),-1)                                  # reshape
        x = self.bn1(self.fc(x))                                  # pass image features through trainable fc layer and batch norm, input = Num of images, output = emb_dim
        #x = self.fc(x)
        return x

# %% [markdown]
# # Section 2.2 Design the Network: Decoder [10 pts]
# During decoding, we will train a RNN (https://pytorch.org/docs/stable/generated/torch.nn.RNN.html#torch.nn.RNN) to learn the structure of the caption text throught "**Teacher Forcing**". Teacher forcing works by using the teaching signal from the training dataset at the current time step, $target(t)$, as input in the next time step $x(t+1) = target(t)$, rather than the output $y(t)$ generated by the network.
#
# As shown in Figure 1 above, RNN will take three inputs: the *current feature*, hidden state ($h_0$) and cell state ($c_0$). The *current feature* for the first step should be the output of encoder to predict '\<start\>' word. Hidden states for this step should be set to None. Then in the second step '\<start\>' will be passed into RNN as the input, and so on.
#
# To use '\<start\>' or any subsequent word as current feature, get its index from the vocabulary you created, convert it to one-hot vector and pass it through a linear layer to embed into a feature (or you can take advantage of Pytorch’s nn.Embedding which does one-hot encoding + linear layer for you).
#
# For convenience, you might want to 'pad' the captions in a mini-batch to convert them into fixed length. You can use 'pack_padded_sequence' function.

# %%
class Decoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim, num_layers=1, dropout=0):
        """
        Use RNN as decoder for captions.
        :param emb_dim: Embedding dimensions.
        :param hidden_dim: Hidden states dimensions.
        :param num_layers: Number of RNN layers.
        :param vocab_size: The size of Vocabulary.
        :param dropout: the probability for dropout.
        """
        super(Decoder, self).__init__()
        self.max_length = 30  # the maximum length of a sentence, in case it's trapped
        
        #############Your code############
        # you need to implement a Vanilla RNN for the decoder. Take a look at the official documentation.
        # https://pytorch.org/docs/stable/generated/torch.nn.RNN.html#torch.nn.RNN
        
        # one-hot encoding + linear layer
        self.embedding = nn.Embedding(num_embeddings = vocab_size, embedding_dim = emb_dim) # getting embedding from vocab sized vector
        self.fc = nn.Linear(emb_dim, emb_dim) # fully connected layer from latent vector output of resnet to RNN cells
        # vanilla rnn network
        self.vanilla_RNN = nn.RNN(input_size = emb_dim, hidden_size = hidden_dim, num_layers = num_layers, dropout = dropout, batch_first = True) # rNN cell input = embedding dim, output = hidden state size
        # output layer 
        self.output = nn.Linear(hidden_dim, vocab_size) # Wht-1 linear transform of outputted hidden state to size of vocab 
        self.softmax = nn.Softmax(dim=1)                # initializing softmax layer
        self.init_weights()                             # initializing weights
    
    def init_weights(self):
        # Uniform (-0.1, 0.1) weight initialization
        self.embedding.weight.data.uniform_(-0.1, 0.1)
        self.output.weight.data.uniform_(-0.1, 0.1)
        self.output.bias.data.fill_(0)  

    def forward(self, encode_features, captions, lengths):
        """
        Feed forward to generate captions. Note that you need to pad the input so they have the same length
        :param encode_features: output of encoder, size [N, emb_dim]
        :param captions: captions, size [N, max(lengths)]
        :param lengths: a list indicating valid length for each caption. size is (batch_size).
        """
        #############Your Code###################
        # pass features through fc layer
        #feature_layer = self.fc(encode_features).unsqueeze(1)
        feature_layer = encode_features.unsqueeze(1)
        # compute the embedding using one-hot technique and linear function
        self.forward_embedding = self.embedding(captions)
        # concatenate the encoded features from encoder and embeddings
        self.features_enc_emb = torch.cat((feature_layer,self.forward_embedding),1)
        self.features_enc_emb_packed = pack_padded_sequence(self.features_enc_emb,lengths, batch_first=True)
        # feed into RNN.
        ht_1, _ = self.vanilla_RNN(self.features_enc_emb_packed)
        # output layer
        outputs = self.output(ht_1[0])
        return outputs

# %% [markdown]
# # Encoder-decoder [10 pts]
# Now we need to put our encoder and decoder together.
#
# In the sample_generate stage, the idea is to “let the network run on its own”, predicting the next word, and then use the network’s prediction to obtain the next input word. There are at least two ways to obtain the next word.
#
# - **Deterministic**: Take the maximum output at each step.
# - **Stochastic**: Sample from the probability distribution. To get the distribution, we need to compute the weighted softmax of the outputs: $y^i = \exp(o^j/\tau) / \sum_n \exp(o^n/\tau)$, where $o^j$ is the output from the last layer, $n$ is the size of the vocabulary, and $\tau$ is the so-called "temperature". By doing this, you should get a different caption each time.

# %%
class Vanilla_rnn(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim, num_layers=1, dropout=0):
        """
        Encoder-decoder vanilla RNN.
        :param vocab_size: the size of Vocabulary.
        :param emb_dim: the dimensions of word embedding.
        :param hidden_dim: the dimensions of hidden units.
        :param num_layers: the number of RNN layers.
        :param dropout: dropout probability
        """
        super(Vanilla_rnn, self).__init__()
        self.max_length = 30
        self.vocab_size = vocab_size
        self.emb_dim = emb_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.dropout = dropout
        #########Your Code################
        # Encoder: ResNet-50
        self.encoder = Encoder(emb_dim)
        # Decoder: RNN
        self.decoder = Decoder(vocab_size, emb_dim, hidden_dim, num_layers, dropout)

    def forward(self, x, captions, lengths):
        """
        Feed forward.
        :param x: Images, [N, 3, H, W]
        :param captions: encoded captions, [N, max(lengths)]
        :param lengths: a list indicating valid length for each caption. length is (batch_size).
        :return: output logits, usually followed by a softmax layer.
        """
        ##########Your code###################
        # forward passing
        enc_ftrs = self.encoder.forward(Variable(x))
        x = self.decoder.forward(enc_ftrs,captions,lengths)
        return x

    def sample_generate(self, x, states=None, mode='Deterministic', temperature=5.0):
        """
        Generate samples during the evaluation.
        
        :param x: input image
        :param states: rnn states
        :param mode: which mode we use.  
         - 'Deterministic': Take the maximum output at each step.
         - 'Stochastic': Sample from the probability distribution from the output layer.
        :param temperature: will be used in the stochastic mode
        :return: sample_idxs. Word indices. We can use vocab to recover the sentence later.
        """
        self.temp = temperature
        sample_idxs = []  # record the index of your generated words
        #################Your Code##################
        # compute the encoded features
        encode_features = self.encoder.forward(Variable(x))
        inputs = encode_features.unsqueeze(1)
        # decide which mode we use
        if mode == 'Deterministic':
          for i in range(self.max_length):                                     
            ht_1, states = self.decoder.vanilla_RNN(inputs, states)
            output = self.decoder.output(ht_1).squeeze(1)
            _, pred = torch.max(output, dim=1)
            #pred = output.max(1)[1]
            sample_idxs.append(pred.cpu().numpy())
            inputs = self.decoder.embedding(pred).unsqueeze(1)

        elif mode == 'Stochastic':
          # sample from the probability distribution after the softmax
          # Hint: use torch.multinomial() to sample from a distribution.
          for i in range(self.max_length):                                     
            ht_1, states = self.decoder.vanilla_RNN(inputs, states)
            output = self.decoder.output(ht_1).squeeze(1)
            probs = self.decoder.softmax(output/self.temp)
            pred = torch.multinomial(probs.data, 1, replacement=True)
            sample_idxs.append(pred.cpu().numpy())
            inputs = self.decoder.embedding(pred.squeeze(-1)).unsqueeze(1)
          sample_idxs = np.hstack(sample_idxs)

        return sample_idxs

# %% [markdown]
# # Section 2.3 Training [10 pts]
# Train your encoder-decoder. You might also want to check the output sentence every epoch.

# %%
# some hyperparameters, you can change them
## training parameters
batch_size = 256
lr = 1e-2
num_epochs = 50
weight_decay = 0.0
log_step = 50

## network architecture
emb_dim = 1024
hidden_dim = 256
num_layers = 1 # number of RNN layers
dropout = 0.0

## image transformation
transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        #     transforms.RandomCrop(224, pad_if_needed=True),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.485, 0.456, 0.406),
                             std=(0.229, 0.224, 0.225))])

## Output directory
output_dir = path_to_homework + '/checkpoints/rnn/'
os.makedirs(output_dir, exist_ok=True)

## device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Validation code here. We are gonna use this during the training. 
def val(model, data_loader, vocab):
    """
    Inputs:
    :param model: the encoder-decoder network.
    :param data_loader: validation data loader
    :param vocab: pre-built vocabulary
    Output:
    the mean value of validation losses
    """
    from dataloader import Flickr30k, get_loader
    print('Validating...')
    val_loss = []
    total_step = len(val_data_loader) #changed to val_data_loader was data_loader
    for itr, (images, captions, lengths) in enumerate(val_data_loader):   #changed to val_data_loader was data_loader
        #######Your Code#########
        # forward inputs and compute the validation loss
        images_features = model.encoder.forward(Variable(images.to(device)))
        captions = Variable(captions).to(device)
        targets = pack_padded_sequence(captions, lengths, batch_first=True)[0]
        outputs = model.decoder.forward(images_features, captions, lengths)
        loss = criterion(outputs, targets)
        # record the validation loss
        val_loss.append(loss.data.detach().cpu().numpy())

        # Print current loss
        if itr % log_step == 0:
            print('Step [{}/{}], Loss: {:.4f}, Perplexity: {:5.4f}'
                  .format(itr, total_step, loss.item(), np.exp(loss.item())))

    # (optional) you might also want to print out the sentence to see the qualitative performance of your model. 
    # You can use deterministic mode to generate sentences
    sample_idxs = np.array(model.sample_generate(images.to(device), mode="Deterministic", temperature=1.0)).T
    captions_list = []
    for i, sentence in enumerate(sample_idxs):  # every sentence in this batch
      sentence_caption = ''
      j = 0
      for word_idx in sentence:
        j += 1
        word = vocab.idx2word[word_idx]
        if word != '<start>' and word != '<end>':
          if word == '.':
            sentence_caption += '.'
          else:
            sentence_caption += word + ' '
        if word == '<end>':
          break
        #print(j,"th word in ", i,"th sentence is ", word)  
      captions_list.append({'caption': sentence_caption})#.detach().cpu().numpy())
    print(captions_list)
 
    return np.mean(val_loss)

# %%
# Training code here

from dataloader import Flickr30k, get_loader

train_data_loader = get_loader(root=path_to_homework, split='train', vocab=vocab, 
                               transform=transform, batch_size=batch_size, shuffle=True, num_workers=4)
val_data_loader = get_loader(root=path_to_homework, split='val', vocab=vocab, 
                               transform=transform, batch_size=8, shuffle=True, num_workers=4)

model = Vanilla_rnn(vocab_size=len(vocab), emb_dim=emb_dim, hidden_dim=hidden_dim, 
                   num_layers=1, dropout=dropout).to(device)  # build a model

# loss and optimizer
criterion = nn.CrossEntropyLoss().to(device)  # CE loss
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)  # optimizer
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)  # decay LR by a factor of 0.5 every 10 epochs. You can change this

# logs
Train_Losses = []  # record average training loss each epoch
Val_Losses = []   # record average validation loss each epoch
total_step = len(train_data_loader)  # number of iterations each epoch
best_val_loss = np.inf

#sample_idxs = np.array(model.sample_generate(images.to(device), mode="Deterministic", temperature=1.0)).T
#print(np.shape(sample_idxs))
#captions_list = []
#for i, sentence in enumerate(sample_idxs):  # every sentence in this batch
#  sentence_caption = ''
  #j=1
#  for word_idx in sentence:
   #print(j,"th word in ", i,"th sentence is ", vocab.idx2word[word_idx])
#   sentence_caption += vocab.idx2word[word_idx] + ' '
#   j+=1
#  captions_list.append({'caption': sentence_caption})
#  if i == 1:
#    print(captions_list)
#  if i>1:
#    break

# start training
print('Start training...')
import time
tic = time.time()
for epoch in range(num_epochs):
    print('Switch to training...')
    model.train()
    Train_loss_iter = []  # record the the training loss each iteration
    scheduler.step()
    for itr, (images, captions, lengths) in enumerate(train_data_loader):
        ########Your Code###########
        # train your model
        optimizer.zero_grad()
        model.encoder.zero_grad()
        images_features = model.encoder.forward(Variable(images.to(device)))
        captions = Variable(captions).to(device)
        targets = pack_padded_sequence(captions, lengths, batch_first=True)[0]
        model.decoder.zero_grad()
        outputs = model.decoder.forward(images_features, captions, lengths)
        loss = criterion(outputs, targets).to(device)
        loss.backward()
        optimizer.step()
        # record the training loss
        Train_loss_iter.append(loss.data.detach().cpu().numpy())
        
        # print log info
        if itr % log_step == 0:
            # print current loss and perplexity
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Perplexity: {:5.4f}'
                      .format(epoch, num_epochs, itr, total_step, loss.item(), np.exp(loss.item())))
        #print("for loop completed")
    Train_Losses.append(np.mean(Train_loss_iter))
    np.save(os.path.join(output_dir, 'TrainingLoss_rnn.npy'), Train_Losses)  # save the training loss
    
    model.eval()
    # (optional) generate a sample during the training, you can use deterministic mode
    # Your code
    sample_idxs = np.array(model.sample_generate(images.to(device), mode="Deterministic", temperature=1.0)).T
    captions_list = []
    for i, sentence in enumerate(sample_idxs):  # every sentence in this batch
      sentence_caption = ''
      j = 0
      for word_idx in sentence:
        j += 1
        word = vocab.idx2word[word_idx]
        if word != '<start>' and word != '<end>':
          if word == '.':
            sentence_caption += '.'
          else:
            sentence_caption += word + ' '
        if word == '<end>':
          break
        #print(j,"th word in ", i,"th sentence is ", word)  
      captions_list.append({'caption': sentence_caption})#.detach().cpu().numpy())
    print(captions_list)

    # validation
    Val_Losses.append(val(model, val_data_loader, vocab))
    np.save(os.path.join(output_dir, 'ValLoss_rnn.npy'), Val_Losses) # save the val loss
    
    # save model
    if Val_Losses[-1] < best_val_loss:
        best_val_loss = Val_Losses[-1]
        print('updated best val loss:', best_val_loss)
        print('Save model weights to...', output_dir)
        torch.save(model.state_dict(), 
                   os.path.join(output_dir, 'vanilla_rnn-best.pth'.format(epoch + 1, itr + 1)))

print('It took: {} s'.format(time.time() - tic))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))
# Start training...
# Switch to training...
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:123: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Epoch [0/50], Step [0/114], Loss: 9.2409, Perplexity: 10310.1273
# Epoch [0/50], Step [50/114], Loss: 3.8712, Perplexity: 47.9996
# Epoch [0/50], Step [100/114], Loss: 3.6009, Perplexity: 36.6310
# [{'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a young man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a woman in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a woman in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a woman in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a young man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a brown dog runs through the grass .'}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a bl ...
# Validating...
# Step [0/127], Loss: 3.7991, Perplexity: 44.6616
# Step [50/127], Loss: 3.6445, Perplexity: 38.2623
# Step [100/127], Loss: 3.6831, Perplexity: 39.7680
# [{'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a young man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}, {'caption': 'a man in a black coat and a woman in a red shirt and a woman in a red shirt and a woman in a red shirt and a '}]
# updated best val loss: 3.5646055
# Save model weights to... /content/drive/My Drive/DL_Fall_2020/Assignment_4//checkpoints/rnn/
# Switch to training...
# Epoch [1/50], Step [0/114], Loss: 3.5747, Perplexity: 35.6853
# Epoch [1/50], Step [50/114], Loss: 3.3796, Perplexity: 29.3591
# Epoch [1/50], Step [100/114], Loss: 3.3698, Perplexity: 29.0718
# [{'caption': 'a man in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a man is sitting on a bench in front of a large building .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a girl in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench in front of a large building .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man in a black shirt and a blue shirt is walking down a street with a large white umbrella .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a man in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a small brown dog is running through the grass .'}, {'caption': 'a man in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench in front of a large building .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is riding a bike on a field .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a brown dog is running through the grass .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a man is sitting on a bench in front of a large building .'}, {'caption': 'a man in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a man in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is riding a bike on a field .'}, {'caption': 'a brown dog is running through the grass .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a man in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a woman in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a man in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a girl is sitting on a bench .'}, {'caption': 'a man in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a man in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a man is sitt ...
# Validating...
# Step [0/127], Loss: 3.1957, Perplexity: 24.4271
# Step [50/127], Loss: 3.6522, Perplexity: 38.5576
# Step [100/127], Loss: 3.0185, Perplexity: 20.4601
# [{'caption': 'a man in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a woman in a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black shirt and a black '}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is walking on a sidewalk .'}, {'caption': 'a man is sitting on a bench .'}]
# updated best val loss: 3.4245439
# Save model weights to... /content/drive/My Drive/DL_Fall_2020/Assignment_4//checkpoints/rnn/
# Switch to training...
# Epoch [2/50], Step [0/114], Loss: 3.3284, Perplexity: 27.8931
# Epoch [2/50], Step [50/114], Loss: 3.2697, Perplexity: 26.3042
# Epoch [2/50], Step [100/114], Loss: 3.1840, Perplexity: 24.1429
# [{'caption': 'a man in a white shirt is standing next to a woman in a white shirt .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is jumping over a miniature golf .'}, {'caption': 'a man in a white shirt is standing on a bench .'}, {'caption': 'a man in a white shirt is sitting on a bench .'}, {'caption': 'a man is standing on a bench .'}, {'caption': 'a man is wearing a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'a man is standing on a bench .'}, {'caption': 'a man is wearing a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'a man in a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'a man is standing on a bench .'}, {'caption': 'a young boy in a blue shirt is running through the air .'}, {'caption': 'a man in a white shirt is standing on a bench .'}, {'caption': 'a group of people are standing on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man in a red shirt is standing next to a woman in a brown sweater is standing next to a woman in a white shirt .'}, {'caption': 'a man is standing on a bench .'}, {'caption': 'a girl in a pink shirt and black boots , and a pink blouse , and a pink blouse , and a pink blouse , and a pink blouse '}, {'caption': 'a man is jumping over a miniature golf .'}, {'caption': 'a young girl in a pink shirt is sitting on a bench .'}, {'caption': 'a man in a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'a man in a white shirt is standing on a bench .'}, {'caption': 'a black dog is running through the air .'}, {'caption': 'a man is wearing a white shirt and black boots is standing next to a woman in a white shirt .'}, {'caption': 'a man in a pink shirt is standing on a bed .'}, {'caption': 'people are gathered on a street .'}, {'caption': 'a man is walking down the street .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man in a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'a young girl in a pink shirt is sitting on a bench .'}, {'caption': 'a man is standing next to a woman in a white shirt .'}, {'caption': 'a man is walking on a skateboard .'}, {'caption': 'a man is walking down the street .'}, {'caption': 'a young boy in a pink shirt is sitting on a bench .'}, {'caption': 'a man in a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'a man in a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a man in a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'people are gathered at a farmers market .'}, {'caption': 'a man in a blue shirt is running through the air .'}, {'caption': 'a man in a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'a girl in a pink shirt is sitting on a bench .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is standing on a bench .'}, {'caption': 'a young boy in a pink shirt is sitting on a bench .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a little boy in a pink shirt and black shorts and a red shirt , and a pink blouse , and a pink blouse , and a pink blouse '}, {'caption': 'a man is standing on a bench .'}, {'caption': 'a man is wearing a red shirt is standing next to a woman in a white shirt .'}, {'caption': 'two women , one in a red shirt and black boots is standing next to a woman in a white shirt .'}, {'caption': 'a man in a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'a young boy in a pink shirt is sitting on a bed .'}, {'caption': 'two men are playing soccer .'}, {'caption': 'a black dog is running through the air .'}, {'caption': 'a man is standing on a bench .'}, {'caption': 'a man in a red shirt is running through the air .'}, {'caption': 'a black dog is r ...
# Validating...
# Step [0/127], Loss: 3.2805, Perplexity: 26.5883
# Step [50/127], Loss: 3.1387, Perplexity: 23.0736
# Step [100/127], Loss: 3.4752, Perplexity: 32.3051
# [{'caption': 'a young boy in a blue shirt is running through the air .'}, {'caption': 'a man is sitting on a bench .'}, {'caption': 'a man is standing on a bench .'}, {'caption': 'a man in a blue shirt is running through the air .'}, {'caption': 'a man in a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'a young boy in a pink shirt is running through the air .'}]
# updated best val loss: 3.302937
# Save model weights to... /content/drive/My Drive/DL_Fall_2020/Assignment_4//checkpoints/rnn/
# Switch to training...
# Epoch [3/50], Step [0/114], Loss: 3.2828, Perplexity: 26.6491
# Epoch [3/50], Step [50/114], Loss: 3.2442, Perplexity: 25.6410
# Epoch [3/50], Step [100/114], Loss: 3.1638, Perplexity: 23.6598
# [{'caption': 'a man in a red jacket and a red jacket is standing on a roof of a building .'}, {'caption': 'a basketball game is played in a field .'}, {'caption': 'a man in a red jacket and jeans is walking down a street .'}, {'caption': 'a man in a red jacket and blue jeans is standing on a roof of a building .'}, {'caption': 'a young girl is playing a guitar .'}, {'caption': 'a man in a red jacket and a man walking down a street .'}, {'caption': 'a man in a red jacket and jeans is walking through a large metal tub filled with graffiti on the ground .'}, {'caption': 'a brown dog is running through the field .'}, {'caption': 'a man in a red jacket and a red jacket is standing on a roof of a building .'}, {'caption': 'a brown dog is running through the field .'}, {'caption': 'a man in a red jacket and blue jeans is standing on a roof of a building .'}, {'caption': 'a large crowd of people are walking down a street .'}, {'caption': 'a man in a red jacket and a red jacket is standing on a roof of a building .'}, {'caption': 'a man in a red jacket and a red jacket is standing on a roof of a building .'}, {'caption': 'a young girl is playing soccer .'}, {'caption': 'a man in a red jacket and a red jacket is standing on a roof of a building .'}, {'caption': 'a man in a red jacket and jeans is walking down a street .'}, {'caption': 'a man in a red jacket and blue jeans is standing on a roof of a building .'}, {'caption': 'a man in a red jacket and jeans is walking down a street .'}, {'caption': 'a man in a red jacket and blue jeans is standing on a roof of a building .'}, {'caption': 'a soccer player in a red and white jersey is hitting a volleyball .'}, {'caption': 'a man in a red jacket and blue jeans is standing on a roof of a building .'}, {'caption': 'a man in a red jacket and blue jeans is riding a bicycle .'}, {'caption': 'a man in a red jacket and jeans is walking down a street .'}, {'caption': 'a man in a red jacket and jeans is walking through a large metal tub filled with graffiti on the ground .'}, {'caption': 'a brown dog is running through the field .'}, {'caption': 'a man in a red jacket is standing in front of a building .'}, {'caption': 'a man in a red shirt is standing on a dock .'}, {'caption': 'a young girl is playing a game of basketball .'}, {'caption': 'a group of people are walking down a street .'}, {'caption': 'a man in a red jacket and a man in a red jacket and jeans is walking down a street .'}, {'caption': 'a man in a red jacket and blue jeans is standing on a roof of a building .'}, {'caption': 'a girl is standing on a dock .'}, {'caption': 'a man in a blue shirt and jeans is walking down a street .'}, {'caption': 'a man in a white t-shirt and jeans is standing on a roof of a building .'}, {'caption': 'a man in a white t-shirt and jeans is standing on a roof of a building .'}, {'caption': 'a brown dog is running through the field .'}, {'caption': 'a man in a red jacket and jeans is walking down a street .'}, {'caption': 'a man in a red shirt is standing on a dock .'}, {'caption': 'a man in a red jacket and jeans is walking through a large metal tub filled with graffiti on the ground .'}, {'caption': 'a man in a red jacket and blue jeans is standing on a roof of a building .'}, {'caption': 'a man in a red jacket and jeans is walking through a large metal tub filled with graffiti on the ground .'}, {'caption': 'a man is riding a bicycle .'}, {'caption': 'a man in a red jacket and jeans is walking down a street .'}, {'caption': 'a man in a red jacket and blue jeans is standing on a roof of a building .'}, {'caption': 'a man in a blue shirt and jeans is walking down a street .'}, {'caption': 'a brown and white dog is running through a field .'}, {'caption': 'a man in a red jacket and a man walking down a street .'}, {'caption': 'a man in a red jacket and a red jacket is standing in front of a building .'}, {'caption': 'a man in a red shirt and jeans is standing on a roof of a building .'}, {'caption': 'a man ...
# Validating...
# Step [0/127], Loss: 3.6525, Perplexity: 38.5695
# Step [50/127], Loss: 3.8625, Perplexity: 47.5835
# Step [100/127], Loss: 3.5908, Perplexity: 36.2621
# [{'caption': 'a man in a red jacket and blue jeans is standing on a roof of a building .'}, {'caption': 'a man in a white t-shirt and jeans is walking down a street .'}, {'caption': 'a young girl is playing a guitar .'}, {'caption': 'a man in a red shirt and jeans is standing in front of a building .'}, {'caption': 'a man in a white t-shirt and jeans is walking down a street .'}, {'caption': 'a man in a red jacket and a red jacket is standing on a roof of a building .'}]
# updated best val loss: 3.2947416
# Save model weights to... /content/drive/My Drive/DL_Fall_2020/Assignment_4//checkpoints/rnn/
# Switch to training...
# Epoch [4/50], Step [0/114], Loss: 3.2027, Perplexity: 24.5976
# Epoch [4/50], Step [50/114], Loss: 2.9810, Perplexity: 19.7071
# Epoch [4/50], Step [100/114], Loss: 3.0059, Perplexity: 20.2038
# [{'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a group of people are walking down the street .'}, {'caption': 'a woman in a pink dress is walking down the street .'}, {'caption': 'a woman in a black dress is walking down the street .'}, {'caption': 'a man in a white shirt is riding a motorcycle .'}, {'caption': 'a young girl in a pink dress is holding a camera .'}, {'caption': 'a woman in a pink dress is walking down the street .'}, {'caption': 'a man in a black shirt is walking down the street .'}, {'caption': 'a group of people are sitting at a table with a microphone .'}, {'caption': 'a man is riding a motorcycle .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a woman in a black dress is walking down the street .'}, {'caption': 'a football player in a red jersey is running .'}, {'caption': 'a man in a black shirt is sitting on a bench in front of a large amount of people .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a man in a black shirt is walking down the street .'}, {'caption': 'a man in a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'a man in a black shirt is sitting on a bench in front of a large amount of people .'}, {'caption': 'a man in a white shirt and blue jeans is walking down a street .'}, {'caption': 'a man in a black shirt is standing next to a woman in a white shirt .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a group of people are walking down the street .'}, {'caption': 'a woman in a black dress is sitting on a bench .'}, {'caption': 'a dog jumps over a hurdle .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is walking down the street .'}, {'caption': 'a little girl in a pink shirt is walking on the sidewalk .'}, {'caption': 'a woman in a black dress is walking down the street .'}, {'caption': 'a man in a black shirt is walking down the street .'}, {'caption': 'a black dog is running through the grass .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a man in a black shirt is walking down the street .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a group of people are walking down the street .'}, {'caption': 'a skier is skiing down a river .'}, {'caption': 'a man in a black shirt is walking down a street .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a man in a black shirt is sitting on a bench in front of a large amount of people .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a group of people are walking down the street .'}, {'caption': 'a man in a black wetsuit is surfing on a surfboard .'}, {'caption': 'a man in a black shirt is walking down the street .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a man is walking on the ground .'}, {'caption': 'a man in a black shirt is walking down a street .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a man in a white shirt is standing next to a man in a black shirt and a white shirt is sitting on a bench .'}, {'caption': 'a group of people are walking down the street .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a young girl in a pink shirt is walking down a street .'}, {'caption': 'a man in a black shirt is riding a motorcycle .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a woman in a black dress is walking down the street .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a man in a black shirt is sitting on a bench in fron ...
# Validating...
# Step [0/127], Loss: 3.3391, Perplexity: 28.1925
# Step [50/127], Loss: 3.0040, Perplexity: 20.1652
# Step [100/127], Loss: 2.6762, Perplexity: 14.5304
# [{'caption': 'a man in a black shirt is riding a motorcycle .'}, {'caption': 'a man is walking on the sidewalk .'}, {'caption': 'a group of people are walking down the street .'}, {'caption': 'a man in a black shirt is walking down the street .'}, {'caption': 'a man in a white shirt is riding a horse .'}, {'caption': 'a man is surfing on a surfboard .'}]
# updated best val loss: 3.1463068
# Save model weights to... /content/drive/My Drive/DL_Fall_2020/Assignment_4//checkpoints/rnn/
# Switch to training...
# Epoch [5/50], Step [0/114], Loss: 2.9775, Perplexity: 19.6377
# Epoch [5/50], Step [50/114], Loss: 2.8629, Perplexity: 17.5114
# Epoch [5/50], Step [100/114], Loss: 2.9422, Perplexity: 18.9568
# [{'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and a '}, {'caption': 'a group of people are standing in a park .'}, {'caption': 'a woman in a white shirt and a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and a '}, {'caption': 'a man is standing on a rock wall .'}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and a '}, {'caption': 'a young girl in a pink shirt and blue pants is riding a bike .'}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a black shirt is standing in front of '}, {'caption': 'a man in a black shirt and a woman in a black shirt and blue pants is riding a bike in a city .'}, {'caption': 'a man in a black shirt is holding a microphone .'}, {'caption': 'a man in a black shirt is holding a microphone .'}, {'caption': 'a man in a black shirt and a woman in a black shirt and blue pants is riding a bike in a city .'}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and a '}, {'caption': 'a woman in a black shirt and a woman in a black shirt and a black shirt is holding a microphone in front of a crowd .'}, {'caption': 'a woman in a white shirt and a white shirt is playing with a toy in a backyard .'}, {'caption': 'a man in a black shirt is holding a microphone .'}, {'caption': 'a man in a black shirt is holding a microphone in front of a crowd .'}, {'caption': 'a young girl in a pink shirt and a white shirt is standing on a rock .'}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and blue '}, {'caption': 'a man in a white shirt is holding a microphone .'}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and a '}, {'caption': 'a man in a black shirt and a woman in a black shirt and a black shirt is holding a microphone in front of a crowd .'}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a black shirt is standing in front of '}, {'caption': 'a man in a black shirt and a white shirt is riding a bike in a city .'}, {'caption': 'a man in a black shirt is holding a microphone .'}, {'caption': 'a man in a white shirt and a woman in a black shirt and a black shirt is sitting on a bench in a city .'}, {'caption': 'a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and a '}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and blue '}, {'caption': 'a young boy in a blue shirt and a white shirt is standing on a rock .'}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a black shirt is sitting on a couch '}, {'caption': 'a man in a white shirt is holding a microphone .'}, {'caption': 'a man in a black shirt and a white shirt is riding a bike in a forest .'}, {'caption': 'a man in a black shirt is holding a microphone .'}, {'caption': 'a man in a white shirt is holding a microphone in front of a crowd .'}, {'caption': 'a young boy in a blue shirt and a white shirt is standing on a rock .'}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and a '}, {'caption': 'a man in a white shirt is holding a microphone .'}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a blue shirt is standing in front of '}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and a '}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a b ...
# Validating...
# Step [0/127], Loss: 3.2646, Perplexity: 26.1698
# Step [50/127], Loss: 3.2114, Perplexity: 24.8143
# Step [100/127], Loss: 2.8940, Perplexity: 18.0645
# [{'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and a '}, {'caption': 'a man in a blue shirt and a woman in a black shirt and a woman in a black shirt and blue pants is riding a bike in a '}, {'caption': 'a man in a white shirt is holding a cellphone .'}, {'caption': 'a man in a black shirt and a white shirt is riding a bike in a forest .'}, {'caption': 'a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and a woman in a black shirt and a '}, {'caption': 'a man in a black shirt and a woman in a black shirt and a woman in a black shirt and a black shirt is holding a microphone in '}]
# updated best val loss: 3.0680315
# Save model weights to... /content/drive/My Drive/DL_Fall_2020/Assignment_4//checkpoints/rnn/
# Switch to training...
# Epoch [6/50], Step [0/114], Loss: 2.8330, Perplexity: 16.9970
# Epoch [6/50], Step [50/114], Loss: 2.9363, Perplexity: 18.8453
# Epoch [6/50], Step [100/114], Loss: 2.9290, Perplexity: 18.7081
# [{'caption': 'a man in a blue jacket is walking on the sidewalk .'}, {'caption': 'a man in a blue shirt and a blue jacket is walking on the sidewalk .'}, {'caption': 'a boy in a blue jacket is jumping into the water .'}, {'caption': 'a man in a blue shirt and a blue shirt is jumping into the water .'}, {'caption': 'a man in a blue shirt is looking at a map .'}, {'caption': 'a group of people in a field sponsored by a crowd .'}, {'caption': 'a man in a blue swimsuit is jumping into the water .'}, {'caption': 'a man in a blue jacket is walking down a sidewalk .'}, {'caption': 'a man in a blue shirt and a blue jacket is walking on the sidewalk .'}, {'caption': 'a young girl in a blue shirt is holding a large stick .'}, {'caption': 'a woman in a blue jacket is walking on the sidewalk .'}, {'caption': 'a crowd of people are standing in front of a crowd of people .'}, {'caption': 'a man in a white shirt and a white baseball mitt runs in the middle of a stadium .'}, {'caption': 'a man in a blue shirt and a blue shirt is walking in the street .'}, {'caption': 'a woman in a blue dress is walking on the sidewalk .'}, {'caption': 'a man in a blue shirt and a blue shirt is walking in the street .'}, {'caption': 'a man in a blue shirt is playing a guitar .'}, {'caption': 'a man in a blue shirt and a blue jacket is walking on the sidewalk .'}, {'caption': 'a man in a blue shirt and a blue shirt is walking in the street .'}, {'caption': 'a man in a blue shirt is singing into a microphone .'}, {'caption': 'a man in a blue jacket is walking on the sidewalk .'}, {'caption': 'a man in a blue shirt and a blue jacket is walking on the sidewalk .'}, {'caption': 'a man in a blue shirt and a blue jacket is walking on the sidewalk .'}, {'caption': 'a dog jumps over a hurdle .'}, {'caption': 'a woman in a pink shirt and a blue jacket is walking on the sidewalk .'}, {'caption': 'a group of people are walking on the beach .'}, {'caption': 'a woman in a blue shirt is walking on the sidewalk .'}, {'caption': 'a man is jumping into the water .'}, {'caption': 'a man in a blue shirt and a blue jacket is walking on the sidewalk .'}, {'caption': 'a man in a bl
# Save model weights to... /content/drive/My Drive/DL_Fall_2020/Assignment_4//checkpoints/rnn/
# Switch to training...
# Epoch [9/50], Step [0/114], Loss: 2.8233, Perplexity: 16.8324
# Epoch [9/50], Step [50/114], Loss: 2.7231, Perplexity: 15.2279
# Epoch [9/50], Step [100/114], Loss: 2.7319, Perplexity: 15.3614
# ...
# Validating...
# Step [0/127], Loss: 2.7872, Perplexity: 16.2358
# Step [50/127], Loss: 2.9802, Perplexity: 19.6919
# Step [100/127], Loss: 3.5594, Perplexity: 35.1412
# [{'caption': 'a man in a blue shirt is riding a bike in a parking lot .'}, {'caption': 'a brown dog is running through the snow .'}, {'caption': 'a group of people are sitting at a table with a table in a restaurant .'}, {'caption': 'a woman in a blue shirt is sitting on a bench in front of a building .'}, {'caption': 'a girl in a pink shirt is playing with a ball in the grass .'}, {'caption': 'a man in a blue shirt is walking down the street .'}]
# Switch to training...
# Epoch [47/50], Step [0/114], Loss: 2.4114, Perplexity: 11.1498
# Epoch [47/50], Step [50/114], Loss: 2.3253, Perplexity: 10.2296
# Epoch [47/50], Step [100/114], Loss: 2.3684, Perplexity: 10.6807
# [{'caption': 'a young boy in a blue shirt is running in a race .'}, {'caption': 'a woman in a black dress and a man in a black shirt and black pants is playing a guitar .'}, {'caption': 'a young girl is sitting in a chair with a baby in a hospital bed .'}, {'caption': 'a man in a black shirt is walking down the street .'}, {'caption': 'a little girl in a pink shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt and blue jeans is walking down a sidewalk .'}, {'caption': 'a group of people are sitting at a table with a table in a restaurant .'}, {'caption': 'a man in a red shirt is holding a camera .'}, {'caption': 'a man in a blue shirt and jeans is sitting on a bench in front of a building .'}, {'caption': 'a man in a black jacket is walking down the street .'}, {'caption': 'a man in a black shirt is walking down the street .'}, {'caption': 'a woman in a white shirt is holding a baby .'}, {'caption': 'a group of people are walking through a park .'}, {'caption': 'a man in a white shirt and black pants is riding a bike in a parking lot .'}, {'caption': 'a man in a blue shirt is walking down the street .'}, {'caption': 'a man is walking on the beach .'}, {'caption': 'a gymnast is performing a jump on a trampoline .'}, {'caption': 'a dog is running through the water .'}, {'caption': 'a man in a black shirt and black pants is walking down the street .'}, {'caption': 'a man is standing in front of a building .'}, {'caption': 'a group of people are walking through a park .'}, {'caption': 'a man in a red shirt and blue jeans is walking through the snow .'}, {'caption': 'a man in a white shirt and black pants is walking down the street .'}, {'caption': 'a woman in a black dress and a man in a black shirt and a woman in a black shirt and black pants is standing in front of a '}, {'caption': 'a woman in a white dress and a black skirt is walking down a sidewalk .'}, {'caption': 'a man in a black jacket is walking down the street .'}, {'caption': 'a man in a blue shirt and jeans is standing on a ladder .'}, {'caption': 'a man in a white shirt is playing a guitar and singing .'}, {'caption': 'a man in a black shirt is playing a guitar .'}, {'caption': 'a man is sitting on a rock in a river .'}, {'caption': 'a man in a blue shirt is riding a horse .'}, {'caption': 'a woman in a white shirt and black shorts is running in a race .'}, {'caption': 'a man in a blue shirt is standing in front of a store window .'}, {'caption': 'a man and woman are sitting at a table with a table in a restaurant .'}, {'caption': 'a man in a red jacket is standing on a rock in the snow .'}, {'caption': 'a woman in a red shirt is holding a red toy .'}, {'caption': 'a woman in a red dress and a black dog is playing with a ball in the air .'}, {'caption': 'a man in a blue shirt is sitting on a rock .'}, {'caption': 'a young boy in a blue shirt is playing with a toy .'}, {'caption': 'a woman in a black shirt is sitting in a chair with a white shirt and a woman in a black shirt .'}, {'caption': 'a man in a blue shirt and jeans is standing on a rock .'}, {'caption': 'a man in a blue shirt and jeans is sitting on a bench in front of a building .'}, {'caption': 'a basketball player in a red uniform is about to throw a ball .'}, {'caption': 'a man is kayaking in the ocean .'}, {'caption': 'a man in a black shirt is playing a guitar .'}, {'caption': 'a man in a blue shirt is standing in front of a store window .'}, {'caption': 'a brown dog is running through the water .'}, {'caption': 'a woman in a white shirt and black shorts is running in a field .'}, {'caption': 'a young boy in a blue shirt is sitting on a rock .'}, {'caption': 'a group of people are walking down a street .'}, {'caption': 'a man in a white shirt is playing a guitar .'}, {'caption': 'a man and a woman are sitting at a table with a table in a restaurant .'}, {'caption': 'a man in a black shirt is walking down the street .'}, {'caption': '
'}, {'caption': 'a man in a blue shirt is sitting on a bench in front of a building .'}, {'caption': 'a man in a red shirt and blue jeans is walking through a stream .'}, {'caption': 'a man in a black shirt and a woman in a white dress and a black dress are dancing .'}, {'caption': 'a group of people are walking in the street .'}, {'caption': 'a man in a white shirt is holding a microphone .'}, {'caption': 'a man and a woman are walking down the street .'}, {'caption': 'a woman in a black shirt and a woman ...
# Validating...
# Step [0/127], Loss: 2.7907, Perplexity: 16.2921
# Step [50/127], Loss: 2.7292, Perplexity: 15.3206
# Step [100/127], Loss: 3.0555, Perplexity: 21.2327
# [{'caption': 'a group of people are walking down a street .'}, {'caption': 'two men are playing soccer on a field .'}, {'caption': 'a young boy in a blue shirt is running in a race .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a group of people are gathered in a park .'}, {'caption': 'a man in a black jacket is walking down the street .'}]
# It took: 16106.622640609741 s

# %% [markdown]
# # Section 2.4 Evaluation [10 pts]

# %%
## evaluation code
from tqdm import tqdm, tqdm_notebook
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import SmoothingFunction
smoother = SmoothingFunction()

def caption_generator(model, images, vocab, img_ids, captions, mode='Deterministic', temperature=1.0):
    """
    Generate captions.
    :param mode:
    :return:
    """
    sample_idxs = np.array(model.sample_generate(images, mode=mode,temperature=temperature)).T  #.data.detach().cpu().numpy()  # [N, max_length]
    for i, sentence in enumerate(sample_idxs):  # every sentence in this batch
        sentence_caption = ''
        for word_idx in sentence:
          hash(tuple(np.array([1,2,3,4])))
          word = vocab.idx2word[word_idx]
          if word != '<start>' and word != '<end>':
            if word == '.':
              sentence_caption += '.'
            else:
              sentence_caption += word + ' '
          if word == '<end>':
            break
        captions.append({'caption': sentence_caption})#.detach().cpu().numpy())
        # captions.append(sentence_caption)

    return captions

def run_test(model, data_loader, vocab, mode='Deterministic', temperature=1.0):
    """
    Run your model on the test set.
    Inputs:
    :param model: the model you use
    :param data_loader: the data_loader
    :param mode: use 'deterministic' or 'stochastic'
    Outputs:
    :param predictions
    """
    predictions = []
    for itr, (images, captions, lengths) in enumerate(tqdm(data_loader)):
        images = Variable(images).to(device)
        captions = Variable(captions).to(device)
        outputs = model(images, captions, lengths)
        
        img_ids = list(range(itr * data_loader.batch_size, (itr + 1) * data_loader.batch_size))
        predictions = caption_generator(model, images, vocab, img_ids, 
                                        predictions, mode=mode, temperature=temperature)
        
    return predictions

def evaluation(model, vocab, data_path=path_to_homework + '/flickr30k_images/', mode='Deterministic', temperature=1.0,
               split='test'):
    """
    Evaluate the performance of your model on the test set using BLEU scores.
    Inputs:
    :param model: the model you use
    :param weight_path: the directory to the weights of your model
    :param vocab: vocabulary
    :param data_path: the directory to the dataset
    :param mode: use 'deterministic' or 'stochastic'
    Outputs:
    :param predictions
    """
    # data loader
    test_data_loader = get_loader(root=path_to_homework, split=split, vocab=vocab, 
                                  transform=transform, batch_size=8, shuffle=False, num_workers=4)
    
    # run your model on the test set
    print('Run on the test set...')
    preds = run_test(model, test_data_loader, vocab, mode, temperature)
    
    # load the groundtruth
    gt = test_data_loader.dataset.annos
    
    # evaluate the performance using BLEU score
    score1 = 0
    score2 = 0
    score3 = 0
    score4 = 0
    
    print('Computing BLEU')
    for itr in tqdm(range(len(gt))):
        candidate = preds[itr]['caption']
        reference = [sent['raw'] for sent in gt[itr]['sentences']]
        score1 += sentence_bleu(reference, candidate, weights=(1, 0, 0, 0), smoothing_function=smoother.method1)
        score2 += sentence_bleu(reference, candidate, weights=(0, 1, 0, 0), smoothing_function=smoother.method1)
        score3 += sentence_bleu(reference, candidate, weights=(0, 0, 1, 0), smoothing_function=smoother.method1)
        score4 += sentence_bleu(reference, candidate, weights=(0, 0, 0, 1), smoothing_function=smoother.method1)
    
    bleu1 = 100 * score1/len(gt)
    bleu2 = 100 * score2/len(gt)
    bleu3 = 100 * score3/len(gt)
    bleu4 = 100 * score4/len(gt)
    
    return bleu1, bleu2, bleu3, bleu4

# %% [markdown]
# - Test your outputs in the **Deterministic** way by using BLEU scores. You should at achieve a BLEU 4 of 25.

# %%
## Evaluate your model using BLEU score. Use Deterministic mode.

## Image transformation
transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        #     transforms.RandomCrop(224, pad_if_needed=True),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.485, 0.456, 0.406),
                             std=(0.229, 0.224, 0.225))])

## Evaluate your model using BLEU score. Use Deterministic mode
model = Vanilla_rnn(vocab_size=len(vocab), emb_dim=emb_dim, hidden_dim=hidden_dim, 
                   num_layers=1, dropout=dropout).to(device)  # build a model
model.load_state_dict(torch.load(path_to_homework + '/checkpoints/rnn/vanilla_rnn-best.pth', map_location=torch.device('cpu')))
model.eval()
bleu1, bleu2, bleu3, bleu4 = evaluation(model, vocab, mode='Deterministic')
print("BLEU 1:{}, BLEU 2:{}, BLEU 3:{}, BLEU 4:{}".format(bleu1, bleu2, bleu3, bleu4))
# Out:
#   0%|          | 0/125 [00:00<?, ?it/s]
# Run on the test set...
# 100%|██████████| 125/125 [02:14<00:00,  1.07s/it]
#   2%|▏         | 24/1000 [00:00<00:04, 237.01it/s]
# Computing BLEU
# 100%|██████████| 1000/1000 [00:04<00:00, 238.29it/s]
# BLEU 1:86.38888936126274, BLEU 2:60.480425264138226, BLEU 3:37.11497029993314, BLEU 4:24.9989094135853

# %% [markdown]
# - Try different temperatures (e.g. 0.1, 0.2, 0.5, 1.0, 1.5, 2, etc.) during the generation. Report BLEU scores for at least 3 different temperatures.

# %%
## Use at least 3 different temperatures to generate captions on the test set. Report the BLEU scores.
# Your code here
bleu1, bleu2, bleu3, bleu4 = evaluation(model, vocab, mode='Stochastic', temperature = 0.1)
print("Temp = 0.1    BLEU 1:{}, BLEU 2:{}, BLEU 3:{}, BLEU 4:{}".format(bleu1, bleu2, bleu3, bleu4))
bleu1, bleu2, bleu3, bleu4 = evaluation(model, vocab, mode='Stochastic', temperature = 0.2)
print("Temp = 0.2    BLEU 1:{}, BLEU 2:{}, BLEU 3:{}, BLEU 4:{}".format(bleu1, bleu2, bleu3, bleu4))
bleu1, bleu2, bleu3, bleu4 = evaluation(model, vocab, mode='Stochastic', temperature = 0.5)
print("Temp = 0.5    BLEU 1:{}, BLEU 2:{}, BLEU 3:{}, BLEU 4:{}".format(bleu1, bleu2, bleu3, bleu4))
bleu1, bleu2, bleu3, bleu4 = evaluation(model, vocab, mode='Stochastic', temperature = 1.0)
print("Temp = 1.0    BLEU 1:{}, BLEU 2:{}, BLEU 3:{}, BLEU 4:{}".format(bleu1, bleu2, bleu3, bleu4))
# End of code
# Out:
#   0%|          | 0/125 [00:00<?, ?it/s]
# Run on the test set...
# 100%|██████████| 125/125 [00:10<00:00, 11.61it/s]
#   4%|▍         | 41/1000 [00:00<00:02, 403.99it/s]
# Computing BLEU
# 100%|██████████| 1000/1000 [00:02<00:00, 407.11it/s]
# Temp = 0.1    BLEU 1:23.37968758918638, BLEU 2:13.698538646391782, BLEU 3:6.97289505997023, BLEU 4:3.8396880332073913
#   0%|          | 0/125 [00:00<?, ?it/s]
# Run on the test set...
# 100%|██████████| 125/125 [00:10<00:00, 11.78it/s]
#   4%|▍         | 42/1000 [00:00<00:02, 413.75it/s]
# Computing BLEU
# 100%|██████████| 1000/1000 [00:02<00:00, 419.01it/s]
# Temp = 0.2    BLEU 1:24.103054164328146, BLEU 2:14.154914170877342, BLEU 3:7.1572139422041, BLEU 4:3.991791426168762
#   0%|          | 0/125 [00:00<?, ?it/s]
# Run on the test set...
# 100%|██████████| 125/125 [00:10<00:00, 11.55it/s]
#   4%|▍         | 39/1000 [00:00<00:02, 385.08it/s]
# Computing BLEU
# 100%|██████████| 1000/1000 [00:02<00:00, 388.24it/s]
# Temp = 0.5    BLEU 1:26.2012399285663, BLEU 2:16.242482378536657, BLEU 3:8.189481443449402, BLEU 4:4.4111664627101765
#   0%|          | 0/125 [00:00<?, ?it/s]
# Run on the test set...
# 100%|██████████| 125/125 [00:10<00:00, 11.56it/s]
#   4%|▎         | 37/1000 [00:00<00:02, 362.84it/s]
# Computing BLEU
# 100%|██████████| 1000/1000 [00:02<00:00, 346.69it/s]
# Temp = 1.0    BLEU 1:38.343654997896294, BLEU 2:23.93356701327477, BLEU 3:11.05881239671042, BLEU 4:5.439329231543054

# %% [markdown]
# # Section 3 Variations [55 pts]
# ## Section 3.1 LSTM [35 pts]
# ## Section 3.1.1 Decoder: LSTM [5 pts]
# This time, replace the RNN module with an LSTM module.

# %%
class Decoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim, num_layers=1, dropout=0):
        """
        Use LSTM as decoder for captions.
        :param emb_dim: Embedding dimensions.
        :param hidden_dim: Hidden states dimensions.
        :param num_layers: Number of LSTM layers.
        :param vocab_size: The size of Vocabulary.
        :param dropout: dropout probability
        """
        super(Decoder, self).__init__()
        self.max_length = 30  # the maximum length of a sentence, in case it's trapped

        #############Your code############
        # you need to implement a LSTM for the decoder. Take a look at the official documentation.
        # https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html#torch.nn.LSTM
        
        # one-hot encoding + linear layer
        self.embedding = nn.Embedding(num_embeddings = vocab_size, embedding_dim = emb_dim) # getting embedding from vocab sized vector
        self.fc = nn.Linear(emb_dim, emb_dim) # fully connected layer from latent vector output of resnet to LSTM cells
        # LSTM network
        self.lstm = nn.LSTM(input_size = emb_dim, hidden_size = hidden_dim, num_layers = num_layers, dropout = dropout, batch_first = True)
        # output layer
        self.output = nn.Linear(hidden_dim, vocab_size) # Wht-1 linear transform of outputted hidden state to size of vocab
        self.softmax = nn.Softmax(dim=1)                # initializing softmax layer
        self.init_weights()                             # initializing weights

    def init_weights(self):
        # Uniform (-0.1, 0.1) weight initialization
        self.embedding.weight.data.uniform_(-0.1, 0.1)
        self.output.weight.data.uniform_(-0.1, 0.1)
        self.output.bias.data.fill_(0)

    def forward(self, encode_features, captions, lengths):
        """
        Feed forward to generate captions.
        :param encode_features: output of encoder, size [N, emb_dim]
        :param captions: captions, size [N, max(lengths)]
        :param lengths: a list indicating valid length for each caption. length is (batch_size).
        """
        #############Your Code###################
        # pass features through fc layer
        feature_layer = encode_features.unsqueeze(1)
        # compute the embedding using one-hot technique and linear function
        self.forward_embedding = self.embedding(captions)
        # concatenate the encoded features from encoder and embeddings
        self.features_enc_emb = torch.cat([feature_layer,self.forward_embedding],1)
        self.features_enc_emb_packed = pack_padded_sequence(self.features_enc_emb,lengths, batch_first=True)        
        # feed into LSTM
        ht_1, _ = self.lstm(self.features_enc_emb_packed)
        # output layer
        outputs = self.output(ht_1[0])
        return outputs
        #############Your Code##################

# %% [markdown]
# ## Encoder-Decoder [5 pts]

# %%
class LSTM(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim, num_layers=1, dropout=0):
        """
        Encoder-decoder vanilla RNN.
        :param vocab_size: the size of Vocabulary.
        :param emb_dim: the dimensions of word embedding.
        :param hidden_dim: the dimensions of hidden units.
        :param num_layers: the number of RNN layers.
        """
        super(LSTM, self).__init__()
        self.max_length = 30
        self.vocab_size = vocab_size
        self.emb_dim = emb_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.dropout = dropout
        #########Your Code################
        # Encoder: ResNet-50
        self.encoder = Encoder(emb_dim)
        # Decoder: LSTM
        self.decoder = Decoder(vocab_size, emb_dim, hidden_dim, num_layers, dropout)

    def forward(self, x, captions, lengths):
        """
        Feed forward.
        :param x: Images, [N, 3, H, W]
        :param captions: encoded captions, [N, max(lengths)]
        :param lengths: a list indicating valid length for each caption. length is (batch_size).
        :return: output logits, usually followed by a softmax layer.
        """
        ##########Your code###################
        # forward passing
        enc_ftrs = self.encoder.forward(Variable(x))
        x = self.decoder.forward(enc_ftrs,captions,lengths)
        return x

    def sample_generate(self, x, states=None, mode='Deterministic', temperature=5.0):
        """
        Generate samples during the evaluation.
        
        :param x: input image
        :param states: rnn states
        :param mode: which mode we use.  
         - 'Deterministic': Take the maximum output at each step.
         - 'Stochastic': Sample from the probability distribution from the output layer.
        :param temperature: will be used in the stochastic mode
        :return: sample_idxs. Word indices. We can use vocab to recover the sentence.
        """
        self.temp = temperature
        sample_idxs = []
        #################Your Code##################
        # compute the encoded features
        encode_features = self.encoder.forward(Variable(x))
        inputs = self.decoder.fc(encode_features).unsqueeze(1)
        #print (inputs.size())
        # decide which mode we use
        if mode == 'Deterministic':
          for i in range(self.max_length):                                     
            ht_1, states = self.decoder.lstm(inputs, states)
            output = self.decoder.output(ht_1).squeeze(1)
            _, pred = torch.max(output, dim=1)
            sample_idxs.append(pred.cpu().numpy())
            inputs = self.decoder.embedding(pred).unsqueeze(1)

        elif mode == 'Stochastic':
          # sample from the probability distribution after the softmax
          # Hint: use torch.multinomial() to sample from a distribution.
          for i in range(self.max_length):                                     
            ht_1, states = self.decoder.lstm(inputs, states)
            output = self.decoder.output(ht_1).squeeze(1)
            #probs = nn.Softmax(self.decoder.linear(ht_1.squeeze(1))/self.temp)
            probs = self.decoder.softmax(output.div(self.temp))
            pred = torch.multinomial(probs.data, 1, replacement=True)
            sample_idxs.append(pred.cpu().numpy())
            inputs = self.decoder.embedding(pred.squeeze(-1)).unsqueeze(1)
          sample_idxs = np.hstack(sample_idxs)

        return sample_idxs

# %% [markdown]
# ## Section 3.1.2 Training [10 pts]
# Use the same set of hyper-parameters (hidden units, optimizer, learning rate etc.) for both models.

# %%
# some hyperparameters, you can change them
## training parameters
batch_size = 256
lr = 1e-2
num_epochs = 50
weight_decay = 0.0
log_step = 50

## network architecture
emb_dim = 1024
hidden_dim = 256
num_layers = 1 # number of RNN layers
dropout = 0.0

## image transformation
transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        #     transforms.RandomCrop(224, pad_if_needed=True),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.485, 0.456, 0.406),
                             std=(0.229, 0.224, 0.225))])

## Output directory
output_dir = path_to_homework + '/checkpoints/lstm/'
os.makedirs(output_dir, exist_ok=True)

# %%
# Training code here
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


train_data_loader = get_loader(root=path_to_homework, split='train', vocab=vocab,
                               transform=transform, batch_size=batch_size, shuffle=True, num_workers=12)
val_data_loader = get_loader(root=path_to_homework, split='val', vocab=vocab,
                             transform=transform, batch_size=8, shuffle=True, num_workers=4)

model = LSTM(vocab_size=len(vocab), emb_dim=emb_dim, hidden_dim=hidden_dim, 
                   num_layers=1, dropout=dropout).to(device)  # build a model

# loss and optimizer
criterion = nn.CrossEntropyLoss().to(device)  # CE loss
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)  # optimizer
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 
                                      step_size=5,
                                      gamma=0.5)  # decay LR by a factor of 0.5 every 10 epochs. You can change this

# logs
Train_Losses = []  # record average training loss each epoch
Val_Losses = []   # record average validation loss each epoch
total_step = len(train_data_loader)  # number of iterations each epoch
best_val_loss = np.inf

# start training
print('Start training...')
import time
tic = time.time()
for epoch in range(num_epochs):
    print('Switch to training...')
    model.train()
    Train_loss_iter = []  # record the the training loss each iteration
    scheduler.step()
    for itr, (images, captions, lengths) in enumerate(train_data_loader):
        ########Your Code###########
        # train your model
        optimizer.zero_grad()
        model.encoder.zero_grad()
        images_features = model.encoder.forward(Variable(images.to(device)))
        captions = Variable(captions).to(device)
        targets = pack_padded_sequence(captions, lengths, batch_first=True)[0]
        model.decoder.zero_grad()
        outputs = model.decoder.forward(images_features, captions, lengths)
        loss = criterion(outputs, targets).to(device)
        loss.backward()
        optimizer.step()
        # record the training loss
        Train_loss_iter.append(loss.data.detach().cpu().numpy())
        
        # print log info
        if itr % log_step == 0:
            # print current loss and perplexity
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Perplexity: {:5.4f}'
                      .format(epoch, num_epochs, itr, total_step, loss.item(), np.exp(loss.item())))
    
    Train_Losses.append(np.mean(Train_loss_iter))
    np.save(os.path.join(output_dir, 'TrainingLoss_lstm.npy'), Train_Losses)  # save the training loss
    
    model.eval()
    # (optional) generate a sample during the training, you can use deterministic mode
    # Your code
    sample_idxs = np.array(model.sample_generate(images.to(device), mode="Deterministic", temperature=1.0)).T
    captions_list = []
    for i, sentence in enumerate(sample_idxs):  # every sentence in this batch
      sentence_caption = ''
      j = 0
      for word_idx in sentence:
        j += 1
        word = vocab.idx2word[word_idx]
        if word != '<start>' and word != '<end>':
          if word == '.':
            sentence_caption += '.'
          else:
            sentence_caption += word + ' '
        if word == '<end>':
          break
        #print(j,"th word in ", i,"th sentence is ", word)  
      captions_list.append({'caption': sentence_caption})#.detach().cpu().numpy())
    print(captions_list)
    
    # validation
    Val_Losses.append(val(model, val_data_loader, vocab))
    np.save(os.path.join(output_dir, 'ValLoss_lstm.npy'), Val_Losses) # save the val loss
    
    # save model
    if Val_Losses[-1] < best_val_loss:
        best_val_loss = Val_Losses[-1]
        print('updated best val loss:', best_val_loss)
        print('Save model weights to...', output_dir)
        torch.save(model.state_dict(), 
                   os.path.join(output_dir, 'lstm-best.pth'.format(epoch + 1, itr + 1)))

print('It took: {} s'.format(time.time() - tic))
# Out:
# Start training...
# Switch to training...
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:123: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Epoch [0/50], Step [0/114], Loss: 9.2077, Perplexity: 9973.4957
# Epoch [0/50], Step [50/114], Loss: 3.6007, Perplexity: 36.6232
# Epoch [0/50], Step [100/114], Loss: 3.3475, Perplexity: 28.4330
# [{'caption': 'a group of people are walking along a beach .'}, {'caption': 'a group of people are walking along a street .'}, {'caption': 'techniques a man in a blue shirt and blue jeans and a white shirt is walking along a beach .'}, {'caption': 'a man in a blue shirt and a hat and a white hat and a white hat , and a white hat , is sitting on a bench .'}, {'caption': 'a man in a white shirt and a hat and a hat and a woman in a blue shirt , and a white shirt , and a white hat '}, {'caption': 'a man in a blue shirt and a hat and a hat and a white hat , and a white hat , is sitting on a bench .'}, {'caption': 'alley .'}, {'caption': 'a man in a blue shirt and a hat and a hat and a white hat , and a white hat , is sitting on a bench .'}, {'caption': 'people in a room .'}, {'caption': 'a man in a blue shirt and a hat and a hat and a white hat , and a white shirt , is sitting on a bench .'}, {'caption': 'a crowd of people in a room .'}, {'caption': 'in front of a crowd .'}, {'caption': 'a man in a blue shirt and a hat and a hat and a white hat , and a white hat , is sitting on a bench .'}, {'caption': 'stainless white shirt and a white hat , and a white hat , and a white hat , and a white hat , is sitting on a bench .'}, {'caption': '.'}, {'caption': 'man in a blue shirt and a white hat and a hat , and a white hat , and a white hat , is sitting on a bench .'}, {'caption': 'mouth a man in a blue shirt and blue jeans and a white shirt is walking along a beach .'}, {'caption': 'a man in a blue shirt and a hat and a hat and a white hat , and a white hat , is sitting on a bench .'}, {'caption': 'a black and white dog is running on the beach .'}, {'caption': 'whom a man in a white shirt and a hat and a hat and a woman in a blue shirt , and a white shirt , and a white '}, {'caption': '13 a man in a blue shirt and blue jeans and a white shirt is walking along a beach .'}, {'caption': 'the street .'}, {'caption': 'gender a group of people are sitting on a bench .'}, {'caption': 'a man in a blue shirt and a hat and a white hat and a white hat and a white hat , and a white shirt , is sitting '}, {'caption': 'a man in a blue shirt and blue jeans and a white shirt is walking along a beach .'}, {'caption': 'hands against a man in a blue shirt and a white hat , and a white hat , and a white hat , and a white hat , and a '}, {'caption': ''}, {'caption': 'man in a blue shirt and a white hat and a hat and a white hat , and a white hat , and a white hat , and a white '}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a man in a blue shirt and a hat and a hat and a woman in a blue shirt , and a white shirt , and a white hat '}, {'caption': 'a man in a blue shirt and a white hat and a red shirt is walking along a street .'}, {'caption': 'a man in a blue shirt and a hat and a hat and a white hat , and a white hat , is sitting on a bench .'}, {'caption': 
# Validating...
# Step [0/127], Loss: 2.7771, Perplexity: 16.0723
# Step [50/127], Loss: 2.6398, Perplexity: 14.0110
# Step [100/127], Loss: 2.8985, Perplexity: 18.1471
# [{'caption': 'a young girl in a pink shirt is holding a baby .'}, {'caption': 'alike a man in a blue shirt is standing on a rock overlooking a large body of water .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'weather a group of people are standing in front of a large building .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing in front of a large building .'}]
# updated best val loss: 3.0080462
# Save model weights to... /content/drive/My Drive/DL_Fall_2020/Assignment_4//checkpoints/lstm/
# Switch to training...
# Epoch [3/50], Step [0/114], Loss: 2.9569, Perplexity: 19.2387
# Epoch [3/50], Step [50/114], Loss: 2.9935, Perplexity: 19.9556
# Epoch [3/50], Step [100/114], Loss: 3.0061, Perplexity: 20.2089
# [{'caption': 'bats .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a young boy in a blue shirt and blue jeans is jumping into the air .'}, {'caption': 'a young boy in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a group of people are playing in a fountain .'}, {'caption': 'a young boy in a blue shirt is sitting on a bench .'}, {'caption': 'a man is standing on a sidewalk next to a man in a blue shirt .'}, {'caption': 'conversations from the other .'}, {'caption': 'a young boy in a blue shirt is sitting on a bench .'}, {'caption': 'a man is sitting on a bench with a large white tablecloth .'}, {'caption': 'a man is sitting on a bench in front of a large rock .'}, {'caption': 'a young boy in a blue shirt is playing with a toy .'}, {'caption': 'a young boy is playing with a toy .'}, {'caption': 'a man is sitting on a bench with a large white tablecloth .'}, {'caption': 'a young boy is playing with a toy .'}, {'caption': 'a young boy in a blue shirt is sitting on a bench .'}, {'caption': 'air balloon spread cola block fence .'}, {'caption': 'with a white tablecloth .'}, {'caption': 'a group of people are walking down a street .'}, {'caption': 'baked popcorn .'}, {'caption': 'a group of people are walking on a beach .'}, {'caption': 'phone call a man in a black shirt and a black hat is walking down a street .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'diners in a white shirt and black pants .'}, {'caption': 'a young boy is playing with a toy in the air .'}, {'caption': 'a man in a black shirt is playing with a toy .'}, {'caption': 'ball .'}, {'caption': 'a young boy is sitting on a bench with a large white tablecloth .'}, {'caption': 'backwards a man in a black shirt and black pants is walking down a street .'}, {'caption': 'a young boy is playing with a toy .'}, {'caption': 'a young boy is sitting on a bench in front of a large rock .'}, {'caption': 'bars in the air .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'dances .'}, {'caption': 'a man in a blue shirt and blue jeans is sitting on a bench .'}, {'caption': 'is sitting on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a black shirt and black pants is riding a bike .'}, {'caption': 'a red and white striped shirt and blue jeans .'}, {'caption': 'activities .'}, {'caption': 'the sky .'}, {'caption': 'a young boy is sitting on a bench .'}, {'caption': 'hills .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a small child is sitting on a bench .'}, {'caption': 'a man is sitting on a bench in front of a large rock .'}, {'caption': 'a woman in a blue shirt and blue jeans , and a white shirt , and a white shirt , and a man in a blue shirt and blue jeans '}, {'caption': ''}, {'caption': 'bikes skills .'}, {'caption': 'a group of people are playing with a large drum .'}, {'caption': 'a young boy in a blue shirt is playing with a toy .'}, {'caption': 'a man is sitting on a bench in front of a building .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a black shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a young boy is sitting on a bench .'}, {'caption': 'a man in a blue shirt and blue jeans is playing with a guitar .'}, {'caption': 'cars .'}, {'caption': 'a young boy in a blue shirt is sitting on a bench .'}, {'caption': 'trees .'}, {'caption': 'a young boy is playing with a toy in the air .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a young boy in a blue shirt is playing with a toy in the air .'}, {'caption': 'each other .'}, {'caption': 'guard being pulled by a large body of water .'}, {'caption': 'someone in a black shirt and blue jeans , and a black shirt , and a man in a black shirt and a black hat , and a  ...
# Validating...
# Step [0/127], Loss: 3.5978, Perplexity: 36.5194
# Step [50/127], Loss: 2.7971, Perplexity: 16.3977
# Step [100/127], Loss: 3.1826, Perplexity: 24.1100
# [{'caption': 'a young boy in a blue shirt is jumping over a pile of water .'}, {'caption': 'air balloon spread glider skills .'}, {'caption': 'a man is surfing on a wave .'}, {'caption': 'a man in a blue shirt is sitting on a bench in front of a large rock .'}, {'caption': 'a young boy is playing with a toy .'}, {'caption': 'onto a red and white dog .'}]
# updated best val loss: 2.9695382
# Save model weights to... /content/drive/My Drive/DL_Fall_2020/Assignment_4//checkpoints/lstm/
# Switch to training...
# Epoch [4/50], Step [0/114], Loss: 2.9329, Perplexity: 18.7827
# Epoch [4/50], Step [50/114], Loss: 2.7196, Perplexity: 15.1748
# Epoch [4/50], Step [100/114], Loss: 2.7891, Perplexity: 16.2669
# [{'caption': 'hills .'}, {'caption': 'a young boy is playing with a toy in a field .'}, {'caption': 'to the camera .'}, {'caption': 'poles .'}, {'caption': 'a woman in a blue shirt is sitting on a bench .'}, {'caption': 'a group of people are walking down a street .'}, {'caption': 'a group of people are playing in a field .'}, {'caption': 'a man in a white shirt is playing with a toy in a field .'}, {'caption': 'a group of people are walking down a street .'}, {'caption': 'a young boy is playing with a toy in a field .'}, {'caption': 'a young boy is playing with a toy in the air .'}, {'caption': 'a group of people are standing in front of a large crowd of people .'}, {'caption': 'camera .'}, {'caption': 'unhappy a young girl in a pink shirt is holding a stick .'}, {'caption': 'in a field .'}, {'caption': 'volcano a <unk> .'}, {'caption': 'a dog is running through the snow .'}, {'caption': 'a young boy is playing with a toy in a field .'}, {'caption': 'a young girl is playing with a toy in the background .'}, {'caption': 'cabana machines .'}, {'caption': 'liberty a man in a black shirt is playing a guitar .'}, {'caption': 'a young girl in a pink shirt is holding a baby in a stroller .'}, {'caption': 'a man in a white shirt is sitting on a couch .'}, {'caption': 'can see a man in a white shirt .'}, {'caption': 'water .'}, {'caption': 'a man in a black shirt is playing a guitar .'}, {'caption': 'a man in a black shirt is playing a guitar and singing into a microphone .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a young girl is playing with a toy .'}, {'caption': 'a man in a white shirt is sitting on a couch .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a young girl is playing with a toy in a field .'}, {'caption': 'a young boy is jumping on a trampoline .'}, {'caption': 'flags .'}, {'caption': 'a woman in a white shirt is holding a baby in a stroller .'}, {'caption': 'a group of people are standing on a beach .'}, {'caption': 'a young girl is playing with a toy in a field .'}, {'caption': 'down a street .'}, {'caption': 'bound a man in a black shirt is standing on a rock in the woods .'}, {'caption': 'a group of people are standing in front of a large crowd of people .'}, {'caption': 'pressure a man in a blue shirt is holding a red and white dog .'}, {'caption': 'a woman in a blue shirt is sitting on a couch .'}, {'caption': 'bound county a group of people are standing on a beach .'}, {'caption': 'a young girl is playing with a toy vacuum .'}, {'caption': 'a dog is running through the snow .'}, {'caption': 'a young girl is playing with a toy vacuum .'}, {'caption': 'a man in a blue shirt is playing with a toy in a field .'}, {'caption': 'assisted approached by a man in a white shirt and a man in a blue shirt .'}, {'caption': 'legos a man in a black shirt and a man in a black shirt and a man in a black shirt and a man in a black shirt .'}, {'caption': 'beer .'}, {'caption': 'a man in a black shirt and jeans is sitting on a bench .'}, {'caption': 'a man in a blue shirt is holding a stick .'}, {'caption': 'a young girl is playing with a toy in a field .'}, {'caption': 'clothespins green hills .'}, {'caption': 'a man in a black shirt is playing a guitar and singing into a microphone .'}, {'caption': 'a white and white dog is playing with a red toy .'}, {'caption': 'wheeler mower .'}, {'caption': 'a man in a black shirt is standing in front of a crowd
are sitting on a rock in the woods .'}, {'caption': 'a group of people are standing in a line on a street .'}, {'caption': 'a group of people are standing in a circle on a park bench .'}, {'caption': 'floor with a <unk> <unk> in the background .'}, {'caption': 'knelt approached exposure a woman in a pink shirt is playing the violin .'}, {'caption': 'a man and a woman are sitting on a couch .'}, {'caption': 'a woman in a black shirt is playing with a toy .'}, {'caption': 'a man in a black shirt is standing in front of a crowd of people .'}, {'caption': 'a man in a black shirt is playing a guitar .'}, {'caption': 'plains .'}, {'caption': 'castles spectating a man in a blue shirt is playing with a toy .'}, {'caption': 'overlooked a woman in a white shirt is holding a microphone .'}, {'caption': 'a young boy is playing with a toy .'}, {'caption': 'a large group of people are in a large room with a large white and red dog .'}, {'caption': 'dunes installation , and a man in a black shirt are sitting on a couch .'}, {'caption': 'line into a <unk> .'}, {'caption': 'leaves from the sky .'}, {'caption': 'tusks tips rack pressure a man in a white shirt and black shorts is jumping into a pool .'}, {'caption': 'a man in a black shirt is playing a guitar .'}, {'caption': 'by a group of people in a large room .'}, {'caption': 'stove a man is standing on a rock in front of a large body of water .'}, {'caption': 'stairs .a large group of people are standing around a large , circular table .'}, {'caption': 'tips a man in a black shirt and jeans is standing in front of a microphone .'}, {'caption': 'a woman in a black shirt is playing a game of tennis .'}, {'caption': 'underpants a man in a white shirt is playing the drums .'}, {'caption': 'also barely seen on the ground .'}, {'caption': 'sleds .'}, {'caption': 'tips on a street corner .'}, {'caption': 'a group of people are standing in a field .'}, {'caption': 'aerosol cans forming a pyramid .'}, {'caption': 'legos a man in a white shirt is standing in front of a crowd .'}, {'caption': 'balloons nearby maintains festivities cue sparklers a group of people are standing around a fire .'}, {'caption': 'links happening happening mid-jump a basketball player in a white uniform is about to throw the ball .'}, {'caption': 'animals .'}, {'caption': 'a young boy is playing in the water .'}, {'caption': 'struggle waste a young boy in a red shirt is playing with a ball .'}, {'caption': 'air quality played film a large , <unk> of <unk> <unk> <unk> .'}, {'caption': 'a group of people are riding horses .'}, {'caption': 'a young girl in a pink dress is playing with a hula hoop .'}, {'caption': 'a young girl is playing in the water .'}, {'caption': 'donkeys .'}, {'capt ...
# Validating...
# Step [0/127], Loss: 2.2959, Perplexity: 9.9330
# Step [50/127], Loss: 2.5994, Perplexity: 13.4558
# Step [100/127], Loss: 2.3739, Perplexity: 10.7390
# [{'caption': 'a group of people are walking on a path .'}, {'caption': 'bathed in a classroom .'}, {'caption': 'fire for a <unk> .'}, {'caption': 'a young boy is playing a game on a punching bag .'}, {'caption': 'a woman in a white shirt is playing with a toy .'}, {'caption': 'a man in a blue shirt is playing a guitar and singing into a microphone .'}]
# It took: 11879.374456882477 s

# %% [markdown]
# ## Section 3.1.3 Evalution [10 pts]
# Evaluate your model on the test set by perplexity score or BLEU score

# %%
## Evaluate your model using BLEU score. Use Deterministic mode.
# Your code here

## Image transformation
transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        #     transforms.RandomCrop(224, pad_if_needed=True),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.485, 0.456, 0.406),
                             std=(0.229, 0.224, 0.225))])

model = LSTM(vocab_size=len(vocab), emb_dim=emb_dim, hidden_dim=hidden_dim, 
                   num_layers=1, dropout=dropout).to(device)  # build a model
model.load_state_dict(torch.load(path_to_homework + '/checkpoints/lstm/lstm-best.pth', map_location=torch.device('cpu')))
model.eval()
bleu1, bleu2, bleu3, bleu4 = evaluation(model, vocab, mode='Deterministic')
print("BLEU 1:{}, BLEU 2:{}, BLEU 3:{}, BLEU 4:{}".format(bleu1, bleu2, bleu3, bleu4))
# End of code
# Out:
#   0%|          | 0/125 [00:00<?, ?it/s]
# Run on the test set...
# 100%|██████████| 125/125 [00:10<00:00, 11.52it/s]
#   3%|▎         | 26/1000 [00:00<00:03, 256.35it/s]
# Computing BLEU
# 100%|██████████| 1000/1000 [00:03<00:00, 260.73it/s]
# BLEU 1:73.52780287372197, BLEU 2:48.77510578088074, BLEU 3:26.182545223860302, BLEU 4:16.081811245748607

# %%
## Use at least 3 different temperatures to generate captions on the test set. Report the BLEU scores.
# Your code here
bleu1, bleu2, bleu3, bleu4 = evaluation(model, vocab, mode='Stochastic', temperature = 0.1)
print("Temp = 0.1    BLEU 1:{}, BLEU 2:{}, BLEU 3:{}, BLEU 4:{}".format(bleu1, bleu2, bleu3, bleu4))
bleu1, bleu2, bleu3, bleu4 = evaluation(model, vocab, mode='Stochastic', temperature = 0.2)
print("Temp = 0.2    BLEU 1:{}, BLEU 2:{}, BLEU 3:{}, BLEU 4:{}".format(bleu1, bleu2, bleu3, bleu4))
bleu1, bleu2, bleu3, bleu4 = evaluation(model, vocab, mode='Stochastic', temperature = 0.5)
print("Temp = 0.5    BLEU 1:{}, BLEU 2:{}, BLEU 3:{}, BLEU 4:{}".format(bleu1, bleu2, bleu3, bleu4))
bleu1, bleu2, bleu3, bleu4 = evaluation(model, vocab, mode='Stochastic', temperature = 1.0)
print("Temp = 1.0    BLEU 1:{}, BLEU 2:{}, BLEU 3:{}, BLEU 4:{}".format(bleu1, bleu2, bleu3, bleu4))
# End of code
# Out:
#   0%|          | 0/125 [00:00<?, ?it/s]
# Run on the test set...
# 100%|██████████| 125/125 [00:11<00:00, 10.63it/s]
#   4%|▍         | 38/1000 [00:00<00:02, 367.17it/s]
# Computing BLEU
# 100%|██████████| 1000/1000 [00:02<00:00, 404.41it/s]
# Temp = 0.1    BLEU 1:26.514788301477825, BLEU 2:16.84349216983768, BLEU 3:8.149049656612172, BLEU 4:4.14283026776133
#   0%|          | 0/125 [00:00<?, ?it/s]
# Run on the test set...
# 100%|██████████| 125/125 [00:10<00:00, 11.79it/s]
#   4%|▍         | 39/1000 [00:00<00:02, 388.12it/s]
# Computing BLEU
# 100%|██████████| 1000/1000 [00:02<00:00, 395.33it/s]
# Temp = 0.2    BLEU 1:26.091030156456828, BLEU 2:16.71835726669744, BLEU 3:8.249717402400798, BLEU 4:4.328370092901431
#   0%|          | 0/125 [00:00<?, ?it/s]
# Run on the test set...
# 100%|██████████| 125/125 [00:10<00:00, 11.74it/s]
#   4%|▍         | 39/1000 [00:00<00:02, 384.02it/s]
# Computing BLEU
# 100%|██████████| 1000/1000 [00:02<00:00, 397.55it/s]
# Temp = 0.5    BLEU 1:26.2437057165333, BLEU 2:16.443672980879956, BLEU 3:7.796811712952353, BLEU 4:4.020756971745366
#   0%|          | 0/125 [00:00<?, ?it/s]
# Run on the test set...
# 100%|██████████| 125/125 [00:10<00:00, 11.64it/s]
#   3%|▎         | 34/1000 [00:00<00:02, 328.06it/s]
# Computing BLEU
# 100%|██████████| 1000/1000 [00:02<00:00, 357.21it/s]
# Temp = 1.0    BLEU 1:38.32333694776506, BLEU 2:22.98052890383253, BLEU 3:9.550866351797294, BLEU 4:4.31376173613896

# %% [markdown]
# ## Section 3.1.4 Discussion [5 pts]
# What's the difference between Vanilla RNN and LSTM (training loss, evaluation results, etc)?

# %% [markdown]
# **Your comments**: We observe that the vanilla RNN implementation produces better BLEU(4) scores than the LSTM implementation (even though we observe lower training/validation error and lower perplexity scores on the LSTM). We do note that the difference in BLEU scores tends to be less for higher temperature values in the stochastic implementation. We know that LSTM is more suited for learning long term dependencies while RNN can only learn short term dependencies, so generally we expect LSTM to perform better than RNN. It could be that the hyperparameter settings aren't optimized for LSTM or perhaps the specific task presented doesn't really have any significant long term dependencies (maybe most of the captions in our batch are short sentences where each word truly does depend on just the few last words before it), which would make it a suitable problem for vanilla RNN.

# %% [markdown]
# ## Section 3.2 Using pre-trained word embeddings [20 pts]
# For now, the decoder uses a word as input by converting it into a fixed size embedding, and our networks learn these word embeddings by training. In this experiment, you will use pre-trained word embeddings like Word2Vec or GloVe in LSTM. If you use Pytorch’s nn.Embedding layer, you can initialize its weights with a matrix containing pre-trained word embeddings for all words in your vocabulary, and freeze the weights (i.e. don’t train this layer). You can find these embeddings online.
#
# Some resources:
# - GloVe: https://nlp.stanford.edu/projects/glove/
# - Word2Vec: http://jalammar.github.io/illustrated-word2vec/
#
# In case you don't know how to get one, we've already provided a light GloVe embedding: wm_06.npy, which can produce 300-d word embeddings.

# %% [markdown]
# ## Section 3.2.1 Encoder-decoder [10 pts]

# %%
class Decoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim, pretrained_emb, num_layers=1, dropout=0):
        """
        Use LSTM as decoder for captions.
        :param emb_dim: Embedding dimensions.
        :param hidden_dim: Hidden states dimensions.
        :param pretrained_emb: the path to the pretrained embedding
        :param num_layers: Number of LSTM layers.
        :param vocab_size: The size of Vocabulary.
        :param dropout: dropout probability
        """
        super(Decoder, self).__init__()
        self.max_length = 30  # in case it's trapped
        ###### Your Code#########
        # load pre-trained embedding weights and freeze this layer
        glove = np.load(pretrained_emb + '/wm_06.npy', allow_pickle=True)
        glove = torch.from_numpy(glove)
        self.embedding = nn.Embedding.from_pretrained(glove, freeze = True)
        # lstm network
        self.lstm = nn.LSTM(input_size = emb_dim, hidden_size = hidden_dim, num_layers = num_layers, dropout = dropout, batch_first = True)
        # output layer
        self.output = nn.Linear(hidden_dim, vocab_size) # Wht-1 linear transform of outputted hidden state to size of vocab 
        self.softmax = nn.Softmax(dim=1)                # initializing softmax layer
        self.init_weights()                             # initializing weights
    
    def init_weights(self):
        # Uniform (-0.1, 0.1) weight initialization
        self.embedding.weight.data.uniform_(-0.1, 0.1)
        self.output.weight.data.uniform_(-0.1, 0.1)
        self.output.bias.data.fill_(0)    

    def forward(self, encode_features, captions, lengths):
        """
        Feed forward to generate captions.
        :param encode_features: output of encoder, size [N, emb_dim]
        :param captions: captions, size [N, max(lengths)]
        :param lengths: a list indicating valid length for each caption. length is (batch_size).
        """
        #############Your Code###################
        # pass features through fc layer
        feature_layer = encode_features.unsqueeze(1)
        # compute the embedding using one-hot technique and linear function
        self.forward_embedding = self.embedding(captions)
        # concatenate the encoded features from encoder and embeddings
        self.features_enc_emb = torch.cat((feature_layer,self.forward_embedding),1)
        self.features_enc_emb_packed = pack_padded_sequence(self.features_enc_emb,lengths, batch_first=True)
        self.features_enc_emb_packed = self.features_enc_emb_packed.float()        
        # feed into RNN
        ht_1, _ = self.lstm(self.features_enc_emb_packed)
        # output layer
        outputs = self.output(ht_1[0])
        
        return outputs

# %%
class Word_embeddings(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim, pretrained_emb, num_layers=1, dropout=0):
        """
        Encoder-decoder baseline.
        :param vocab_size: the size of Vocabulary.
        :param emb_dim: the dimensions of word embedding.
        :param hidden_dim: the dimensions of hidden units.
        :param pretrained_emb: the path to the pretrained embedding
        :param num_layers: the number of LSTM layers.
        :param dropout: dropout probability.
        """
        super(Word_embeddings, self).__init__()
        self.max_length = 30
        self.vocab_size = vocab_size
        self.emb_dim = emb_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.dropout = dropout
        #########Your Code################
        # Encoder: ResNet-50
        self.encoder = Encoder(emb_dim)
        # Decoder: LSTM
        self.decoder = Decoder(vocab_size, emb_dim, hidden_dim, pretrained_emb, num_layers, dropout)

    def forward(self, x, captions, lengths):
        """
        Feed forward.
        :param x: Images, [N, 3, H, W]
        :param captions: encoded captions, [N, max(lengths)]
        :param lengths: a list indicating valid length for each caption. length is (batch_size).
        :return: output logits, usually followed by a softmax layer.
        """
        ##########Your code###################
        # forward passing
        enc_ftrs = self.encoder.forward(Variable(x))
        x = self.decoder.forward(enc_ftrs,captions,lengths)
        return x

    def sample_generate(self, x, states=None, mode='Deterministic', temperature=5.0):
        """
        Generate samples.
        :param x:
        :return:
        """
        self.temp = temperature
        sample_idxs = []
        #################Your Code##################
        # compute the encoded features
        encode_features = self.encoder.forward(Variable(x))
        inputs = encode_features.unsqueeze(1).float()
        # decide which mode we use
        if mode == 'Deterministic':
          for i in range(self.max_length):                                     
            ht_1, states = self.decoder.lstm(inputs, states)
            output = self.decoder.output(ht_1).squeeze(1)
            _, pred = torch.max(output, dim=1)
            sample_idxs.append(pred.cpu().numpy())
            inputs = self.decoder.embedding(pred).unsqueeze(1).float()    
        elif mode == 'Stochastic':
          # sample from the probability distribution after the softmax
          # Hint: use torch.multinomial() to sample from a distribution.
          for i in range(self.max_length):                                     
            ht_1, states = self.decoder.lstm(inputs, states)
            output = self.decoder.output(ht_1).squeeze(1)
            probs = self.decoder.softmax(output/self.temp)
            pred = torch.multinomial(probs.data, 1, replacement=True)
            sample_idxs.append(pred.cpu().numpy())
            inputs = self.decoder.embedding(pred.squeeze(-1)).unsqueeze(1).float()
          sample_idxs = np.hstack(sample_idxs)    
            
        return sample_idxs

# %% [markdown]
# ## Section 3.2.2 Training [5 pts]

# %%
# some hyperparameters, you can change them
## training parameters
batch_size = 256
lr = 1e-2
num_epochs = 50
weight_decay = 0.0
log_step = 50

## network architecture
emb_dim = 300
hidden_dim = 256
num_layers = 1 # number of RNN layers
dropout = 0.0

## image transformation
transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        #     transforms.RandomCrop(224, pad_if_needed=True),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.485, 0.456, 0.406),
                             std=(0.229, 0.224, 0.225))])

## Output directory
output_dir = path_to_homework + '/checkpoints/pretrained_emb/'
os.makedirs(output_dir, exist_ok=True)

# %%
# Training code here
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


train_data_loader = get_loader(root=path_to_homework, split='train', vocab=vocab,
                               transform=transform, batch_size=batch_size, shuffle=True, num_workers=12)
val_data_loader = get_loader(root=path_to_homework, split='val', vocab=vocab,
                             transform=transform, batch_size=8, shuffle=True, num_workers=4)

# pretrained embedding weights
pre_emb_path = path_to_homework  # type the path to the pretrained embedding you find

model = Word_embeddings(vocab_size=len(vocab), emb_dim=emb_dim, hidden_dim=hidden_dim, pretrained_emb=pre_emb_path,
                   num_layers=1, dropout=dropout).to(device)  # build a model

# loss and optimizer
criterion = nn.CrossEntropyLoss().to(device)  # CE loss
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)  # optimizer
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 
                                      step_size=5,
                                      gamma=0.5)  # decay LR by a factor of 0.5 every 10 epochs. You can change this

# logs
Train_Losses = []  # record average training loss each epoch
Val_Losses = []   # record average validation loss each epoch
total_step = len(train_data_loader)  # number of iterations each epoch
best_val_loss = np.inf

# start training
print('Start training...')
import time
tic = time.time()
for epoch in range(num_epochs):
    print('Switch to training...')
    model.train()
    Train_loss_iter = []  # record the the training loss each iteration
    for itr, (images, captions, lengths) in enumerate(train_data_loader):
        ########Your Code###########
        # train your model
        optimizer.zero_grad()
        model.encoder.zero_grad()
        images_features = model.encoder.forward(Variable(images.to(device)))
        captions = Variable(captions).to(device)
        targets = pack_padded_sequence(captions, lengths, batch_first=True)[0]
        model.decoder.zero_grad()
        outputs = model.decoder.forward(images_features, captions, lengths)
        loss = criterion(outputs, targets).to(device)
        loss.backward()
        optimizer.step()
        # record the training loss
        Train_loss_iter.append(loss.data.detach().cpu().numpy())
        
        # print log info
        if itr % log_step == 0:
            # print current loss and perplexity
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Perplexity: {:5.4f}'
                      .format(epoch, num_epochs, itr, total_step, loss.item(), np.exp(loss.item())))
    scheduler.step()
    Train_Losses.append(np.mean(Train_loss_iter))
    np.save(os.path.join(output_dir, 'TrainingLoss_lstm.npy'), Train_Losses)  # save the training loss
    
    model.eval()
    # (optional) generate a sample during the training, you can use deterministic mode
    # Your code
    sample_idxs = np.array(model.sample_generate(images.to(device), mode="Deterministic", temperature=1.0)).T
    captions_list = []
    for i, sentence in enumerate(sample_idxs):  # every sentence in this batch
      sentence_caption = ''
      j = 0
      for word_idx in sentence:
        j += 1
        word = vocab.idx2word[word_idx]
        if word != '<start>' and word != '<end>':
          if word == '.':
            sentence_caption += '.'
          else:
            sentence_caption += word + ' '
        if word == '<end>':
          break
        #print(j,"th word in ", i,"th sentence is ", word)  
      captions_list.append({'caption': sentence_caption})#.detach().cpu().numpy())
    print(captions_list)
    
    # validation
    Val_Losses.append(val(model, val_data_loader, vocab))
    np.save(os.path.join(output_dir, 'ValLoss_lstm.npy'), Val_Losses) # save the val loss
    
    # save model
    if Val_Losses[-1] < best_val_loss:
        best_val_loss = Val_Losses[-1]
        print('updated best val loss:', best_val_loss)
        print('Save model weights to...', output_dir)
        torch.save(model.state_dict(), 
                   os.path.join(output_dir, 'pretrain-best.pth'.format(epoch + 1, itr + 1)))

print('It took: {} s'.format(time.time() - tic))
# Out:
# Start training...
# Switch to training...
# Epoch [0/50], Step [0/114], Loss: 9.2139, Perplexity: 10035.6462
# Epoch [0/50], Step [50/114], Loss: 4.2254, Perplexity: 68.4044
# Epoch [0/50], Step [100/114], Loss: 3.8366, Perplexity: 46.3658
# [{'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a field .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a sidewalk .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a black dog is running on a field .'}, {'caption': 'a black dog is running on a field .'}, {'caption': 'a man in a blue shirt is standing on a sidewalk .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a man in a blue shirt is standing on a sidewalk .'}, {'caption': 'a man in a blue shirt is sitting on a table .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a sidewalk .'}, {'caption': 'a black dog is running on a field .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a black dog is running on a field .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a black dog is running on a field .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a black dog is running on a field .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is standing on a bench .'} ...
# Validating...
# Step [0/127], Loss: 3.3719, Perplexity: 29.1337
# Step [50/127], Loss: 3.4483, Perplexity: 31.4472
# Step [100/127], Loss: 3.8004, Perplexity: 44.7206
# [{'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is standing on a park .'}, {'caption': 'a man in a blue shirt is standing on a sidewalk .'}, {'caption': 'a man in a blue shirt is standing on a bench .'}, {'caption': 'a black dog is running on a field .'}]
# updated best val loss: 3.690313
# Save model weights to... /content/drive/My Drive/DL_Fall_2020/Assignment_4//checkpoints/pretrained_emb/
# Switch to training...
# Epoch [1/50], Step [0/114], Loss: 3.5464, Perplexity: 34.6887
# Epoch [1/50], Step [50/114], Loss: 3.5064, Perplexity: 33.3267
# Epoch [1/50], Step [100/114], Loss: 3.5023, Perplexity: 33.1933
# [{'caption': 'a man is riding a bike on a beach .'}, {'caption': 'a man in a white shirt is playing a guitar .'}, {'caption': 'a soccer team is playing soccer in the air .'}, {'caption': 'a man in a white shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a man in a white shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is riding a bike on a sidewalk .'}, {'caption': 'a man in a white shirt is sitting on a bench .'}, {'caption': 'a man in a white shirt is sitting on a bench .'}, {'caption': 'a young girl is sitting on a bench .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a soccer team is playing soccer in the air .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a man is riding a bike on a beach .'}, {'caption': 'a man in a white shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a man in a blue shirt is riding a bike on a sidewalk .'}, {'caption': 'a man is riding a bike on a beach .'}, {'caption': 'a man in a white shirt is playing a guitar .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man is riding a bike on a beach .'}, {'caption': 'a man in a white shirt is playing a guitar .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a man is riding a bike on a beach .'}, {'caption': 'a man is riding a bike on a beach .'}, {'caption': 'a young girl is playing with a baby .'}, {'caption': 'a man in a white shirt is playing a guitar .'}, {'caption': 'a man in a white shirt is sitting on a bench .'}, {'caption': 'a group of people are walking on a beach .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a brown dog is running through the water .'}, {'caption': 'a man in a blue shirt is playing a guitar .'}, {'caption': 'a group of people are walking on a beach .'}, {'caption': 'a man is riding a bike on a sidewalk .'}, {'caption': 'a man in a blue shirt is riding a bike .'}, {'caption': 'a man in a white shirt is sitting on a bench .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a man in a white shirt is sitting on a bench .'}, {'caption': 'a man in a white shirt is playing a guitar .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a young boy is jumping on a beach .'}, {'caption': 'a man in a white shirt is playing a guitar .'}, {'caption': 'a man in a white shirt is playing a guitar .'}, {'caption': 'a young girl is sitting on a bench .'}, {'caption': 'a man in a white shirt is sitting on a bench .'}, {'caption': 'a man is riding a bike on a beach .'}, {'caption': 'a man is running on a beach .'}, {'caption': 'a man in a white shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a group of people are sitting on a table .'}, {'caption': 'a man is riding a bike on a beach .'}, {'caption': 'a man in a white shirt is playing a guitar .'}, {'caption': 'a group of people are sitting on a table .'}, {'caption': 'a man is riding a bike on a beach .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a dog is running through the water .'}, {'caption': 'a man in a white shirt is playing a guitar .'}, {'caption': 'a man is walking down a street .'}, {'caption': 'a man is riding a bike on a beach .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a man in a white shirt is playing a guitar .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, ...
# Validating...
# Step [0/127], Loss: 3.1380, Perplexity: 23.0576
# Step [50/127], Loss: 3.6065, Perplexity: 36.8383
# Step [100/127], Loss: 3.7037, Perplexity: 40.5992
# [{'caption': 'a young girl is playing with a baby .'}, {'caption': 'a man in a blue shirt is walking down a street .'}, {'caption': 'a man in a white shirt is sitting on a bench .'}, {'caption': 'a young girl is playing with a baby .'}, {'caption': 'a group of people are sitting on a bench .'}, {'caption': 'a group of people are walking down a street .'}]
# updated best val loss: 3.41671
# Save model weights to... /content/drive/My Drive/DL_Fall_2020/Assignment_4//checkpoints/pretrained_emb/
# Switch to training...
# Epoch
'}, {'caption': 'a man in a blue shirt is walking down the street .'}, {'caption': 'a group of people are standing in front of a large building .'}, {'caption': 'a young boy in a red shirt is playing with a soccer ball .'}, {'caption': 'a group of people are sitting in a circle .'}, {'caption': 'a black and white dog is running through the grass .'}, {'caption': 'a man in a white shirt is standing in front of a large building .'}, {'caption': 'a man in a blue shirt is standing on a sidewalk .'}, {'caption': 'a man in a red shirt is walking down the street .'}, {'caption': 'a man in a white shirt is holding a drink .'}, {'caption': 'a woman in a bikini bathing suit is standing in the water .'}, {'caption': 'a man in a blue shirt is walking down the street .'}, {'caption': 'a man in a blue shirt and jeans is standing on a dirt road .'}, {'caption': 'a basketball player is trying to catch a ball .'}, {'caption': 'a man in a blue shirt is playing a guitar .'}, {'caption': 'a man in a blue shirt is standing in front of a crowd of people .'}, {'caption': 'a man and a woman are walking along a sidewalk .'}, {'caption': 'a man in a red shirt is standing in front of a large tree .'}, {'caption': 'a man in a red shirt is jumping in the air .'}, {'caption': 'a tennis player in a white shirt is throwing a ball .'}, {'caption': 'a man in a black shirt is standing in front of a computer .'}, {'caption': 'a man in a blue shirt and a woman in a black shirt are standing in front of a crowd .'}, {'caption': 'a man in a blue shirt and jeans is standing on a sidewalk .'}, {'caption': 'a man in a red shirt and a woman in a black shirt are standing in front of a crowd .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a white shirt and a woman in a white shirt are walking down the street .'}, {'caption': 'a man in a blue shirt is surfing in the water .'}, {'caption': 'a group of people are sitting at a table with a large screen .'}, {'caption': 'a woman in a white shirt is sitting on a bench .'}, {'caption': 'a black and white dog is running through the grass .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a blue shirt is sitting on a boat .'}, {'caption': 'a group of people are walking down a street .'}, {'caption': 'a man in a red s ...
# Validating...
# Step [0/127], Loss: 3.0382, Perplexity: 20.8684
# Step [50/127], Loss: 2.7781, Perplexity: 16.0885
# Step [100/127], Loss: 2.8421, Perplexity: 17.1510
# [{'caption': 'a man in a blue shirt is standing in front of a counter of food .'}, {'caption': 'a group of people are standing in front of a large crowd .'}, {'caption': 'a dog runs through the grass .'}, {'caption': 'a man in a blue shirt is sitting on a bench .'}, {'caption': 'a man in a red shirt is standing in front of a car .'}, {'caption': 'a man in a blue shirt is jumping off a rock .'}]
# updated best val loss: 2.8865316
# Save model weights to... /content/drive/My Drive/DL_Fall_2020/Assignment_4//checkpoints/pretrained_emb/
# Switch to training...
# Epoch [9/50], Step [0/114], Loss: 2.7562, Perplexity: 15.7403
# Epoch [9/50], Step [50/114], Loss: 2.8024, Perplexity: 16.4848
# Epoch [9/50], Step [100/114], Loss: 2.7757, Perplexity: 16.0498
# ...
# Validating...
# Step [0/127], Loss: 2.3778, Perplexity: 10.7813
# Step [50/127], Loss: 2.6341, Perplexity: 13.9302
# Step [100/127], Loss: 2.5907, Perplexity: 13.3391
# [{'caption': 'a man in a blue shirt and jeans is sitting on a bench .'}, {'caption': 'a black dog is laying on a bed with a dog .'}, {'caption': 'a man in a blue shirt is walking past a building .'}, {'caption': 'a man in a black shirt and jeans is sitting on a bench .'}, {'caption': 'a dog is running through the snow .'}, {'caption': 'a dog is running through a field .'}]
# Switch to training...
# Epoch [47/50], Step [0/114], Loss: 2.4383, Perplexity: 11.4537
# Epoch [47/50], Step [50/114], Loss: 2.5269, Perplexity: 12.5151
# Epoch [47/50], Step [100/114], Loss: 2.6495, Perplexity: 14.1467
woman in a black dress is standing in front of a mirror .'}, {'caption': 'a group of people are playing instruments .'}, {'caption': "a man in a red shirt is holding a sign that says `` <unk> '' ."}, {'caption': 'a group of people are standing in a crowded area .'}, {'caption': 'a man in a red shirt and a helmet is riding a bike .'}, {'caption': 'two men in red and white uniforms are playing soccer .'}, {'caption': 'a woman in a white shirt is sitting on a bench with a dog .'}, {'caption': 'a woman in a white shirt is holding a drink .'}, {'caption': 'a man in a black jacket and black pants is walking down the street .'}, {'caption': 'a black dog is running through the snow .'}, {'caption': 'a baby is laying on a bed .'}, {'caption': 'a man in a blue shirt is riding a dirt bike .'}, {'caption': 'a group of people are standing outside a building .'}, {'caption': 'a dog runs through the grass .'}, {'caption': 'a man and a woman are sitting on a bench in front of a building .'}, {'caption': 'a race car is driving through a muddy track .'}, {'caption': 'a woman in a pink shirt is standing in front of a bus .'}, {'caption': 'a woman in a blue shirt is sitting on a bench .'}, {'caption': 'a woman in a red shirt is sitting on a bench .'}, {'caption': 'two men are talking to each other .'}, {'caption': 'a young boy in a blue shirt is holding a baby .'}, {'caption': 'a man in a black jacket and a woman in a white shirt are walking down the street .'}, {'caption': 'a black dog is running through the water .'}, {'caption': 'two dogs are playing in the water .'}, {'caption': 'a man in ...
# Validating...
# Step [0/127], Loss: 3.0256, Perplexity: 20.6070
# Step [50/127], Loss: 2.7548, Perplexity: 15.7180
# Step [100/127], Loss: 2.4595, Perplexity: 11.6993
# [{'caption': 'a man in a white shirt is sitting at a table with a woman in a blue shirt .'}, {'caption': 'a man in a suit is sitting at a table with a book and a woman in a black shirt .'}, {'caption': 'a little girl in a pink shirt is playing with a toy in a pool .'}, {'caption': 'a man in a blue shirt and jeans is sitting on a bench .'}, {'caption': 'a crowd of people are walking in a city .'}, {'caption': 'people are walking on a beach .'}]
# It took: 13355.0283908844 s

# %% [markdown]
# ## Section 3.2.3 Evaluation [3 pts]

# %%
## Evaluate your model using BLEU score. Use Deterministic mode
model = Word_embeddings(vocab_size=len(vocab), emb_dim=emb_dim, hidden_dim=hidden_dim, pretrained_emb=pre_emb_path,
                   num_layers=1, dropout=dropout).to(device)  # build a model
model.load_state_dict(torch.load(path_to_homework + '/checkpoints/pretrained_emb/pretrain-best.pth', map_location=torch.device('cpu')))
model.eval()
bleu1, bleu2, bleu3, bleu4 = evaluation(model, vocab, mode='Deterministic')
print("BLEU 1:{}, BLEU 2:{}, BLEU 3:{}, BLEU 4:{}".format(bleu1, bleu2, bleu3, bleu4))
# Out:
#   0%|          | 0/125 [00:00<?, ?it/s]
# Run on the test set...
# 100%|██████████| 125/125 [01:15<00:00,  1.65it/s]
#   2%|▏         | 21/1000 [00:00<00:04, 207.32it/s]
# Computing BLEU
# 100%|██████████| 1000/1000 [00:04<00:00, 215.72it/s]
# BLEU 1:87.66987610532668, BLEU 2:61.562102251880205, BLEU 3:38.107669622394106, BLEU 4:25.77652002445662

# %% [markdown]
# ## Section 3.2.4 Discussion [2 pts]
# Compared to index embeddings, do pretrained embeddings improve the performance? Try to explain it.

# %% [markdown]
# **Your Comments**: compared to index embeddings, pretrained embeddings did improve performance, this is because pretrained embeddings are probably better representations of the features of the inputs in the latent space as they have been specifically trained over thousands or millions of datasets to produce word vectors in the latent space which closely capture the latent structure of the input features/the relationships between words.

# %% [markdown]
# ### Guidelines for Downloading PDF in Google Colab
# - Run below cells only in Google Colab, Comment out in case of Jupyter notebook

# %%
#Run below two lines (in google colab), installation steps to get .pdf of the notebook

#!apt-get install texlive texlive-xetex texlive-latex-extra pandoc
#!pip install pypandoc

# After installation, comment above two lines and run again to remove installation comments from the notebook.

# %%
# Find path to your notebook file in drive and enter in below line

# !jupyter nbconvert --to pdf "/content/drive/My Drive/DL_Fall_2020/Assignment_4/MS HW4 final.ipynb"

#Example: "/content/drive/My Drive/DL_Fall_2020/Assignment_4/DL_Assignment_4.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/My Drive/DL_Fall_2020/Assignment_4/MS HW4 final.ipynb to pdf
# [NbConvertApp] Support files will be in MS HW4 final_files/
# [NbConvertApp] Making directory ./MS HW4 final_files
# [NbConvertApp] Writing 1127658 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: [u'xelatex', u'./notebook.tex', '-quiet']
# [NbConvertApp] CRITICAL | xelatex failed: [u'xelatex', u'./notebook.tex', '-quiet']
# This is XeTeX, Version 3.14159265-2.6-0.99998 (TeX Live 2017/Debian) (preloaded format=xelatex)
#  restricted \write18 enabled.
# entering extended mode
# (./notebook.tex
# LaTeX2e <2017-04-15>
# Babel <3.18> and hyphenation patterns for 3 language(s) loaded.
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2014/09/29 v1.4h Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size11.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/tcolorbox/tcolorbox.sty
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/basiclayer/pgf.sty
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/utilities/pgfrcs.sty
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfutil-common.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfutil-common-lists.t
# ex)) (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfutil-latex.def
# (/usr/share/texlive/texmf-dist/tex/latex/ms/everyshi.sty))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfrcs.code.tex))
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/basiclayer/pgfcore.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/xetex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/systemlayer/pgfsys.sty
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsys.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfkeys.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/utilities/pgfkeysfiltered.code.t
# ex)) (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgf.cfg)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsys-xetex.def
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsys-dvipdfmx.def
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsys-common-pdf.de
# f))))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsyssoftpath.code.
# tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/systemlayer/pgfsysprotocol.code.
# tex)) (/usr/share/texlive/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcore.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmath.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathcalc.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathutil.code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathparser.code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.code.tex
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.basic.code
# .tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.trigonomet
# ric.code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.random.cod
# e.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.comparison
# .code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.base.code.
# tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.round.code
# .tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.misc.code.
# tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfunctions.integerari
# thmetics.code.tex)))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/math/pgfmathfloat.code.tex))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepoints.code.te
# x)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepathconstruct.
# code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepathusage.code
# .tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorescopes.code.te
# x)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoregraphicstate.c
# ode.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoretransformation
# s.code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorequick.code.tex
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreobjects.code.t
# ex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepathprocessing
# .code.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorearrows.code.te
# x)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreshade.code.tex
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreimage.code.tex
#
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreexternal.code.
# tex))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorelayers.code.te
# x)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoretransparency.c
# ode.tex)
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepatterns.code.
# tex)))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/modules/pgfmoduleshapes.code.tex
# ) (/usr/share/texlive/texmf-dist/tex/generic/pgf/modules/pgfmoduleplot.code.tex
# )
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/compatibility/pgfcomp-version-0-65
# .sty)
# (/usr/share/texlive/texmf-dist/tex/latex/pgf/compatibility/pgfcomp-version-1-18
# .sty)) (/usr/share/texlive/texmf-dist/tex/latex/tools/verbatim.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/environ/environ.sty
# (/usr/share/texlive/texmf-dist/tex/latex/trimspaces/trimspaces.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/etoolbox/etoolbox.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tcolorbox/tcbbreakable.code.tex
# Library (tcolorbox): 'tcbbreakable.code.tex' version '4.12'
# )) (/usr/share/texlive/texmf-dist/tex/latex/float/float.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty
# (/usr/share/texlive/texmf-dist/tex/latex/base/t1enc.def)
# (/usr/share/texmf/tex/latex/lm/t1lmr.fd))
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/mathpazo.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/caption/caption.sty
# (/usr/share/texlive/texmf-dist/tex/latex/caption/caption3.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/adjustbox/adjustbox.sty
# (/usr/share/texlive/texmf-dist/tex/latex/xkeyval/xkeyval.sty
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkeyval.tex
# (/usr/share/texlive/texmf-dist/tex/generic/xkeyval/xkvutils.tex)))
# (/usr/share/texlive/texmf-dist/tex/latex/adjustbox/adjcalc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/adjustbox/trimclip.sty
# (/usr/share/texlive/texmf-dist/tex/latex/collectbox/collectbox.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/adjustbox/tc-xetex.def))
# (/usr/share/texlive/texmf-dist/tex/latex/ifoddpage/ifoddpage.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/varwidth/varwidth.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/tools/enumerate.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ifpdf.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ifvtex.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/ifxetex/ifxetex.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amssymb.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/base/textcomp.sty
# (/usr/share/texlive/texmf-dist/tex/latex/base/ts1enc.def))
# (/usr/share/texlive/texmf-dist/tex/latex/upquote/upquote.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/eurosym/eurosym.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucs.sty
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-global.def))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty
#
# Package inputenc Warning: inputenc package ignored with utf8 based engines.
#
# ) (/usr/share/texlive/texmf-dist/tex/latex/fancyvrb/fancyvrb.sty
# Style option: `fancyvrb' v2.7a, with DG/SPQR fixes, and firstline=lastline fix
# <2008/02/07> (tvz))
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/grffile.sty
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/kvoptions.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ltxcmds.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/kvsetkeys.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/infwarerr.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/etexcmds.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/ifluatex.sty))))
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/pdftexcmds.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/hyperref/hyperref.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/hobsub-hyperref.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/hobsub-generic.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/auxhook.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/hyperref/pd1enc.def)
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/hyperref.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/url/url.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/hyperref/hxetex.def
# (/usr/share/texlive/texmf-dist/tex/latex/hyperref/puenc.def)
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/stringenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/oberdiek/rerunfilecheck.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/tools/longtable.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/booktabs/booktabs.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/enumitem/enumitem.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/ulem/ulem.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/jknapltx/mathrsfs.sty)
# No file notebook.aux.
# (/usr/share/texlive/texmf-dist/tex/latex/base/ts1cmr.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/t1ppl.fd)
# ABD: EveryShipout initializing macros
# (/usr/share/texlive/texmf-dist/tex/latex/caption/ltcaption.sty)
# *geometry* driver: auto-detecting
# *geometry* detected driver: xetex
# *geometry* verbose mode - [ preamble ] result:
# * driver: xetex
# * paper: <default>
# * layout: <same size as paper>
# * layoutoffset:(h,v)=(0.0pt,0.0pt)
# * modes:
# * h-part:(L,W,R)=(72.26999pt, 469.75502pt, 72.26999pt)
# * v-part:(T,H,B)=(72.26999pt, 650.43001pt, 72.26999pt)
# * \paperwidth=614.295pt
# * \paperheight=794.96999pt
# * \textwidth=469.75502pt
# * \textheight=650.43001pt
# * \oddsidemargin=0.0pt
# * \evensidemargin=0.0pt
# * \topmargin=-37.0pt
# * \headheight=12.0pt
# * \headsep=25.0pt
# * \topskip=11.0pt
# * \footskip=30.0pt
# * \marginparwidth=59.0pt
# * \marginparsep=10.0pt
# * \columnsep=10.0pt
# * \skip\footins=10.0pt plus 4.0pt minus 2.0pt
# * \hoffset=0.0pt
# * \voffset=0.0pt
# * \mag=1000
# * \@twocolumnfalse
# * \@twosidefalse
# * \@mparswitchfalse
# * \@reversemarginfalse
# * (1in=72.27pt=25.4mm, 1cm=28.453pt)
#
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucsencs.def)
# (/usr/share/texlive/texmf-dist/tex/latex/hyperref/nameref.sty
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/gettitlestring.sty))
#
# Package hyperref Warning: Rerun to get /PageLabels entry.
#
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/ot1ppl.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/omlzplm.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/omszplm.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/omxzplm.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/ot1zplm.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/jknapltx/ursfs.fd)
#
# LaTeX Warning: No \author given.
#
# (/usr/share/texlive/texmf-dist/tex/generic/oberdiek/se-ascii-print.def)
# [1]
# Underfull \hbox (badness 10000) in paragraph at lines 452--454
# []\T1/ppl/m/n/10.95 https://cv-tricks.com/wp-content/uploads/2019/07/ResNet50_a
# rchitecture-1.png (Used
#
# Underfull \vbox (badness 10000) detected at line 476
#
# Underfull \hbox (badness 10000) in paragraph at lines 486--487
# []\T1/ppl/m/n/10.95 https://stackoverflow.com/questions/21046417/python-convers
# ion-of-list-of-arrays-to-2d-
#
# Underfull \hbox (badness 10000) in paragraph at lines 488--489
# []\T1/ppl/m/n/10.95 https://stackoverflow.com/questions/27516849/how-to-convert
# -list-of-numpy-arrays-into-
#
# Overfull \hbox (134.48589pt too wide) in paragraph at lines 498--499
# []\T1/ppl/m/n/10.95 https://www.deeplearningwizard.com/deep_learning/practical_
# pytorch/pytorch_recurrent_neuralnetwork/#building-
#
# Overfull \hbox (28.3818pt too wide) in paragraph at lines 502--503
# []\T1/ppl/m/n/10.95 https://github.com/prakashpandey9/Text-Classification-Pytor
# ch/blob/master/models/LSTM.py
#
# Underfull \hbox (badness 10000) in paragraph at lines 504--505
# []\T1/ppl/m/n/10.95 https://medium.com/analytics-vidhya/use-pytorch-to-create-a
# n-image-captioning-model-
#
# Underfull \hbox (badness 10000) in paragraph at lines 508--509
# []\T1/ppl/m/n/10.95 https://www.analyticsvidhya.com/blog/2018/04/solving-an-ima
# ge-captioning-task-using-
#
# Underfull \vbox (badness 10000) detected at line 531
# [2]
# Underfull \hbox (badness 10000) in paragraph at lines 535--536
# []\T1/ppl/m/n/10.95 https://stackoverflow.com/questions/55042931/cudnn-error-cu
# dnn-status-bad-param-can-
# (/usr/share/texmf/tex/latex/lm/t1lmtt.fd) [3]
# (/usr/share/texmf/tex/latex/lm/ts1lmtt.fd)
# Overfull \hbox (16.56783pt too wide) in paragraph at lines 636--640
# []\T1/ppl/m/n/10.95 Step 5: Down-load your kag-gle.json file from https://www.k
# aggle.com/Your_Username/account.
#
# Underfull \hbox (badness 10000) in paragraph at lines 641--643
# []\T1/ppl/m/n/10.95 Step 6: Down-load the dataset. Type \T1/lmtt/m/n/10.95 kagg
# le datasets download
#
# Underfull \hbox (badness 10000) in paragraph at lines 644--646
# []\T1/ppl/m/n/10.95 Step 7: Un-zip the dataset. Type \T1/lmtt/m/n/10.95 unzip f
# lickr-image-dataset.zip
#
# Underfull \hbox (badness 10000) in paragraph at lines 644--646
# \T1/lmtt/m/n/10.95 -x "flickr30k_images/flickr30k_images/flickr30k_images/*.jpg
# " -d
#
# Overfull \hbox (36.01712pt too wide) in paragraph at lines 647--649
# []\T1/ppl/m/n/10.95 Step 8: You should have your dataset in \T1/lmtt/m/n/10.95
# /path-to-Assignment_4/Assignment_4/flickr30k_images/
#
# Underfull \hbox (badness 10000) in paragraph at lines 652--656
# []\T1/ppl/b/n/10.95 Note \T1/ppl/m/n/10.95 that you might want to use \T1/lmtt/
# m/n/10.95 nltk.download(\TS1/lmtt/m/n/10.95 '\T1/lmtt/m/n/10.95 punkt\TS1/lmtt/
# m/n/10.95 '\T1/lmtt/m/n/10.95 ) \T1/ppl/m/n/10.95 and
#
# Overfull \hbox (16.56783pt too wide) in paragraph at lines 662--665
# []\T1/ppl/m/n/10.95 Step 2: Down-load your kag-gle.json file from https://www.k
# aggle.com/Your_Username/account.
# [4]
# Overfull \hbox (294.82654pt too wide) in paragraph at lines 707--707
# []\T1/lmtt/m/n/10.95 unzip flickr-image-dataset.zip -x "flickr30k_images/flickr
# 30k_images/flickr30k_images/*.jpg" -d "/path-to-Assignment_4/Assignment_4/"
# [5] (/usr/share/texlive/texmf-dist/tex/latex/psnfss/ts1ppl.fd) [6]
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.872 ...MS HW4 final_files/MS HW4 final_20_1.png}
#
# ?
# ! Emergency stop.
# <inserted text>
#                 $
# l.872 ...MS HW4 final_files/MS HW4 final_20_1.png}
#
# Output written on notebook.pdf (6 pages).
# Transcript written on notebook.log.
#
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 46644 bytes to /content/drive/My Drive/DL_Fall_2020/Assignment_4/MS HW4 final.pdf
